# %% [markdown]
# # Python for photometry

# %% [markdown]
# ## Python
#
#
# 파이썬은 최근들어 인공 지능, 데이터 사이언스 등의 분야에서 널리 사용되고 있는 언어로 1991년에 발표되었습니다. 파이썬은 실무에서 많이 사용되었던 파이썬 2 버전(v2.7)과 새로운 기능을 계속 업그레이드하고 있는 파이썬 3 버전 (v3.X)이 있는데, 이 두 버전 간의 호환성 문제가 있습니다. 파이썬 2 버전(v2.7)은 현재 더이상 지원되지 않으므로 이 수업에서는 파이썬 3 버전을 기준으로 설명합니다. 버전마다 for문 등의 루프에서 연산 효율이 매우 빨라지는 등 많은 개선이 되므로 최신 버전이 3개월이상 지나 안정화가 된 후에는 귀찮더라도 버전을 반드시 업데이트 하기를 추천합니다.
#
# 파이썬은 다음과 같은 특징이 있습니다.
#
# * 인터프리터 언어로 컴파일을 하지 않고 바로 실행할 수 있다.
# * 무료이며 직관적이고 쉽게 배울수 있어 사용자 층이 많이 늘어나고 있다.
# * 객체 지향 언어로 객체에 대한 속성을 바꾸는 방법을 사용한다. (vs 절차 지향 언어)
# * 과학, 수학 관련 모듈들이 많은 사람들에 의해 개발되어 배포되고 있다.
# * 버전 업데이트가 빠르게 이루어지고 버전간 호환성 문제가 발생할 수 있다.
# * 실행 속도가 느린 편입니다.(개선할 수 있는 방법은 있음)

# %% [markdown]
# ## 설치하기
#
# ### 파이썬(Python) 설치
#
# [파이썬](https://www.python.org/downloads/) 공식 홈페이지에서 제공하는 설치 파일을 다운받아 이용할 수 있습니다. 윈도우, macOS, linux 등 자신의 OS에 맞는  파일을 다운받아 설치하여 사용할 수 있습니다. 하지만 이 방법의 경우 초보자들에게는 모듈 설치나 환경 구성이 어려올 수 있어서 추천하지 않습니다.
#
# 보통은 모듈설치나 가상환경 구성이 편리한 Anaconda, Canopy 등 다른 소프트웨어를 추가로 사용하는 경우가 많습니다.
#
# ```{figure} ./images/python_web.png
# :name: python_web
#
# 파이썬 홈페이지 화면
# ```

# %% [markdown]
# ![python_web.png](data:image/png;base64,...)

# %% [markdown]
# ###  아나콘다 설치
#
# 파이썬을 계속 이용할 계획이 있으면 [아나콘다(Anaconda) 설치](https://anaconda.org/download/)를 권합니다. 윈도우, macOS, linux 등 자신의 OS에 맞는 아나콘다를 설치하면 여러가지 환경 변수들도 설정해 주어 사용이 편리합니다.
#
# 파이썬의 다양한 모듈이 있다는 점은 장점이기도 하지만 여러가지 프로젝트를 실행하다 보면 버전 간의 충돌로 인해 단점이 되기도 합니다. 이때 필요한 것이 가상환경인데 아나콘다를 이용하면 모듈 설치와 가상환경 구성을 매우 쉽게 이용할 수 있습니다.
#
# ```{figure} ./images/python_web.png
# :name: python_web
#
# 파이썬 홈페이지 화면
# ```

# %% [markdown]
# ![c0-anaconda.png](data:image/png;base64,...)

# %% [markdown]
# ## 파이썬 사용 환경
#
# 파이썬을 코딩하는 다양한 방법이 있습니다. 코딩을 하다보면 여러 에러가 발생할 수 있고, 이를 해결하는 과정을 쉽게 할 수 있는 방법이 필요하다. 코딩에 익숙한 전문가들은 텍스트 에디터 만으로 코딩하기도 하는데, 이를 날코딩 이라고 합니다.
#
# 통합 개발 환경(Integrated Development Environment, IDE)은 소프트웨어 개발에 관련된 모든 작업을 할 수 있는 툴을 말합니다. 기본적으로 텍스트 에디터를 기본으로 패키지 인클루딩, 컴파일, 디버그, 원격 서버 액세스, 바이너리 배포 등의 기능을 하나의 프로그램 안에서 모두 처리할 수 있도록 구성됩니다.

# %% [markdown]
# ### 주피터 노트북
#
# 주피터 노트북(Jupyter notebook)은 IPython 쉘을 이용해서 Python 코드가 포함된 동적인 문서를 작성하는 웹어플리케이션입니다. 실행 이후에는 기존 노트를 편집하거나 새로운 노트를 생성하고 편집할 수 있습니다. Jupyter notebook은 ipynb라는 확장자를 가지고 있습니다. 구글 코랩은 Jupyter notebook을 온라인으로 구현해 놓은 것이라고 생각할 수 있습니다.
#
# 다음 화면은 주피터 노트북을 실행한 화면입니다.

# %% [markdown]
# ![Jupyter_notebook_web.png](data:image/png;base64,...)

# %% [markdown]
# #### 주피터 노트북 시작하기
#
# 주피터 노트북을 시작하는 방법은 아래와 같다.
#
#  * 시작 메뉴에서 아이콘을 통해 시작하는 방법
#  * Anaconda prompt에서 jupyter notebook 입력하는 방법

# %% [markdown]
# ![Jupyter_notebook.png](data:image/png;base64,...)

# %% [markdown]
# ![prompt_Jupyter_notebook.png](data:image/png;base64,...)

# %% [markdown]
# #### 셀
#
# 파이썬에서 코드나 텍스트를 입력할 수 있는 요소를 셀이라고 한다. 구글 코랩에서도 텍스트 셀과 코드 셀을 사용할 수 있으며, 각 셀을 클릭하여 쉽게 수정할 수 있다. 또한 셀 추가, 삭제, 위치 이동이 매우 쉬우며 텍스트 셀 / 코드 셀을 상호 변환할 수도 있다. ([참고](https://blog.naver.com/PostView.naver?blogId=nabilera1&logNo=222587254561&parentCategoryNo=&categoryNo=112&viewDate=&isShowPopularPosts=true&from=search))
#
# ```{admonition} 단축키
# * Ctrl + mm : 현재 셀 마크다운 셀로 변환
# * Ctrl + ma : 현재 셀 코드 셀로 변환
# ```

# %% [markdown]
# ##### 텍스트 셀
#
# 텍스트 셀은 Markdown 문법을 사용하며 텍스트 파일로 확장자로는 .md를 주로 사용한다. 텍스트 기반의 마크업 언어로 2004년 존그루버에 의해 만들어졌으며 쉽게 쓰고 읽을 수 있으며 HTML로 변환이 가능하다. 특수기호와 문자를 이용한 매우 간단한 구조의 문법을 사용하여 웹에서도 보다 빠르게 컨텐츠를 작성하고 보다 직관적으로 인식할 수 있다. 자세한 내용은 [Markdown 작성법](https://gist.github.com/ihoneymon/652be052a0727ad59601)을 참고하기 바란다.
#
# 마크다운이 최근 각광받기 시작한 이유는 깃헙(https://github.com) 덕분이다. 깃헙의 저장소Repository에 관한 정보를 기록하는 README.md는 깃헙을 사용하는 사람이라면 누구나 가장 먼저 접하게 되는 마크다운 문서였다. 마크다운을 통해서 설치방법, 소스코드 설명, 이슈 등을 간단하게 기록하고 가독성을 높일 수 있다는 강점이 부각되면서 점점 여러 곳으로 퍼져가게 된다.
#
# ** Markdown 문법의 장점 **
#
# ```{admonition} 장점
# 1. 간결하다.
# 2. 별도의 도구없이 작성가능하다.
# 3. 다양한 형태로 변환이 가능하다.
# 4. 텍스트(Text)로 저장되기 때문에 용량이 적어 보관이 용이하다.
# 5. 텍스트파일이기 때문에 버전관리시스템을 이용하여 변경이력을 관리할 수 있다.
# 6. 지원하는 프로그램과 플랫폼이 다양하다.
# ```
#
# ** Markdown 문법의 단점 **
#
# ```{admonition} 단점
# 1. 표준이 없다.
# 2. 표준이 없기 때문에 도구에 따라서 변환방식이나 생성물이 다르다.
# 3. 모든 HTML 마크업을 대신하지 못한다.
# ```

# %% [markdown]
# ##### 코드 셀
#
# 코드 셀은 런타임과 연결하여 파이썬 코드를 실행할 수 있는 셀이다. 구글 코랩은 사용자들에게 무료 클라우드 GPU 서비스를 제공한다. 약 300만원에 달하는 테슬라 GPU를 제공해 우수한 성능으로 코드를 확인할 수 있다. 특히 성능이 중요시되는 인공지능 모델을 만들때나 많은 양의 데이터를 분석할 때 코랩을 사용하면 빠른 시간 내에 코드 결과를 확인할 수 있다.
#
# 구글 코랩을 사용할 때 드라이브 런타임 최대 수명이 12시간인 가상머신에 연결되는 것이며 일정 시간이 지나면 자동으로 런타임이 끊겨 코드의 실행 결과 등이 초기화된다. 코랩에서 컴퓨팅 리소스를 무료로 제공하기 위해 사용되는 방식이다. 하지만 무조건 12시간이 아니라 최대 12시간 연결을 보장하려 노력하고 입력이 없다면 실제로는 빠른 시간내에 연결이 끊긴다.

# %% [markdown]
# ### VS code 사용
#
# VS code(Visual Studio Code)는 Microsoft에서 제공하는 가벼운 IDE입니다. VS Code는  설치 후 python extension 등 필요한 extension을 인스톨하여 그 기능을 확장하는 형태로 사용합니다. Python 코딩에도 매우 편리하며 주피터 노트북 사용도 매우 편리하게 해 줍니다.
#
# VS code에서는 필요한 extension을 설치를 추천하는데, 위치와 삭제는 간단하며, 다음의 extension을 설치하면 됩니다.
#
# * Python : Microsoft 제공. Python 사용을 위해 필요
#
# * Jupyter : Jupyter 사용을 위해 필요
#
# * Material Icon Theme : 파일 아이콘을 멋이쎄게 보여줌.

# %% [markdown]
# #### VS Code에서 주피터 노트북
#
# 커널을 선택하여 코드 셀을 실행해 보고, 코드 셀과 텍스트 셀을 추가해보시기 바랍니다.

# %% [markdown]
# ![vs_code_jupyter.png](data:image/png;base64,...)

# %% [markdown]
# ## module이란?
#
# Python 에서는 라이브러리 대신 패키지를 다운로드 받고 패키지 안에 있는 module을 이용하는데 module이란 함수나 변수 또는 클래스를 모아 놓은 파일입니다. module은 다른 Python 프로그램에서 불러와 사용할 수 있게끔 만든 Python 파일이라고도 할 수 있습니다.
#
# 우리는 다른 사람들이 이미 만들어 놓은 module을 사용할 수도 있고 우리가 직접 만들어서 사용할 수도 있습니다. Python의 module은 매우 다양하고 실제 프로그래밍을 할 때 여러 module을 사용하게 되는데, 이는 Python의 큰 장점이기도 하면서 module들간의 의존성 문제가 생기는 경우에는 큰 혼란을 겪게 됩니다.
#
# Python module은 다음의 두가지로 나눌 수 있습니다.
#
# 1. 표준 module은 Python 안에 포함된 module로 math, random, datetime, time 등이 있습니다.
#
# 2. 3’rd party module은 외부에서 만들어서 제공하는 module로 따로 설치를 해 주어야 하며 Numpy, Pandas, matplotlib 등이 있습니다.

# %% [markdown]
# ### 표준 module
#
# 파이썬 표준 module은 파이썬을 설치할 때 자동으로 컴퓨터에 설치되는 모듈로 다음과 같은 것들이 있습니다.
#
# * datetime
# * math
# * itertools
# * operator
# * shutil
# * glob
# * pickle
# * os
# * zipfile
# * threading
# * tempfile
# * traceback
# * json
# * urllib

# %% [markdown]
# ### 3’rd party module
#
# 3’rd party module을 사용하기 위해서는 호환되는 버전의 module을 미리 설치되어 있어야 합니다.
#
# Python의 장점 중의 하나가 다양한 모듈이 개발되어 제공되고 있다는 점이고, 단점 중의 하나는 버전이 빠르게 바뀌고, 버전 간에 호환되지 않는 경우가 있을수 있다는 것입니다.

# %% [markdown]
# ## 모듈 설치 및 버전 확인
#
# 아래 셀을 실행하면 이 노트북을 실행하는데 필요한 모듈을 설치하고 파이썬 및 관련 모듈의 버전을 확인할 수 있습니다.

# %%
#import sys
#!pip install photutils==1.12

# %% [markdown]
# ### ModuleNotFountError
#
# 미리 설치되어 있지 않은 3’rd party module을 import 하면 아래와 같은 에러가 발생하게 됩니다.
#
# 이는 모듈을 올바른 경로에 설치하여야만 제대로 import되며 해결이 됩니다.

# %% [markdown]
# ## module 설치

# %% [markdown]
# ### pip 설치
#
# pip(Pip Installs Packages)는 Python 모듈(패키지)를 설치하고 관리하는 패키지 매니저(Package Manager)로 MacOS에서 brew, node의 npm, yarn, Linux에서 apt와 같은 개념의 패키지 매니저 입니다.
#
# 패키지를 다운 받는 가장 보편적이고 간편한 방법은 " pip install 패키지 "을 이용하는 방법입니다. pip 명령어를 사용하게 되면 PyPI에 등록되어 있는 패키지를 검색하여 이를 다운로드 받아 설치할 수 있습니다.
#
# 아래 코드를 입력하여 pip가 설치되어 있는지 확인해 봅시다.
#
# > %는 매직 코멘트 입니다.

# %%
# %pip

# %% [markdown]
# 주피터 노트북에서는 다음과 같은 메직 코멘트를 이용하여 pip 명령어를 사용할 수 있습니다.
#
# >!pip install SomePackage  (SomePackage 설치하기)
#
# >!pip uninstall SomePackage  (SomePackage 삭제하기)
#
# >!pip install SomePackage==1.0.4 (SomePackage 특정 버전 설치하기)
#
# >!pip install --upgrade SomePackage (SomePackage 최신 버전으로 업그레이드 하기)
#
# >!pip list (설치된 패키지 목록 출력하기)
#
# 이 명령어는 구글 코랩에서도 그대로 동작하므로 코랩에 설치되지 않은 모듈은 이와 같은 방법으로 설치가 가능합니다.

# %%
# !pip install Basemap

# %% [markdown]
# ### Anaconda 설치
#
# anaconda (https://www.anaconda.com/download/) 를 사용하면 모듈 설치를 편리하게 할 수 있습니다.
#
# pip는 Python의 정식 지원을 받는 패키지만을 관리하는 관리자이고,
# conda는 anaconda에서 지원 받는 패키지 만을 관리하는 관리자입니다.
#
# 또한 pip는 Python만 한정된 패키지 관리자이고, conda는 Python 뿐만 아니라 c, java 등이 포함된 패키지 관리자입니다.
#
# conda가 pip보다 패키지 의존성을 더 잘 관리해주고, 운영체제 플랫폼에 맞추어진 미리 빌드된 패키지들이 설치되기 때문에 빌드 환경설정이 필요 없습니다. 그리고 conda 패키지는 어떤 패키지를 upgrade or downgrade 하면, 해당 버전에 따라 의존되는 패키지들도 함께 upgrade or downgrade를 해줍니다.
#
# Anaconda prompt에서 다음과 같이 입력하여 module을 설치할 수 있습니다.
#
# >conda install SomePackage (SomePackage 설치 하기)
#
# >conda remove SomePackage (SomePackage 삭제 하기)
#
# >conda install SomePackage=1.0.4 (SomePackage 특정 버전 설치하기)
#
# >conda update SomePackage (SomePackage 업데이트 하기)
#
# > conda update --all (해당 가상환경에 설치된 모든 패키지를 update)
#
# 아쉽지만 구글 코랩에서는 Anaconda가 설치되어 있지 않아 pip를 사용해야 합니다.

# %%
# !conda

# %% [markdown]
# ## module 사용하기

# %% [markdown]
# ### module 불러오기
#
# module을 사용하기 위해서는 다음과 같이 먼저 module을 불러와야 합니다.
#
# > import module_name
#
# 예를 들어 이름이 'math'인 module은 아래와 같이 불러올 수 있습니다.
#
# > import math

# %%
import math

# %% [markdown]
# ### module 안에 저장된 함수와 변수 알아보기
#
# module 안에 표함되어 있는 함수나 변수를 알고 싶으면 아래의 두 명령어로 필요한 정보를 얻을 수 있습니다.
#
# > help(moduleName)
#
# > dir(moduleName)
#
#
# 예를 들어 이름이 'math'인 module안에 들어 있는 함수나 변수를 알고 싶으면
#
# > dir(math)

# %%
import math
print("help(math):", help(math))

# %% [markdown]
# import math
# print("dir(math):", dir(math))

# %% [markdown]
# ### module의 함수, 변수 사용하기
#
# module 안에 표함되어 있는 함수나 변수를 사용하기 위해서는 다음과 같이 사용한다.
#
# > module_name.function_name()
#
# > module_name.variable_name

# %%
print(f"math.sin(0.5): {math.sin(0.5)}")
print(f"math.e: {math.e}")

# %% [markdown]
# ### 특정 함수/변수 하나만 불러 오기
#
# 'math'라는 module의 여러 함수 중에서 이름이 'pi'인 변수만을 불러올 경우에는 아래와 같이 입력한다.
#
# > from math import pi

# %%
from math import pi
print(f"pi: {pi}")

# %% [markdown]
# ### sub package, subsub package 불러오기
#
# 'fits' 라는 이름의 subsub 인 경우, 즉 ssub ∈ sub ∈ module 인 경우에는 아래와 같이 불러올 수 있습니다.

# %%
from astropy.io import fits

# %% [markdown]
# 'matplotlib'라는 이름의 package에 'pyplot' 함수를 'plt'라는 이름으로 사용하고자 한다면 다음과 같이 불러올 수 있습니다.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# (larger).(smaller).(even_smaller)와 같은 형식으로 패키지를 사용할 수 있습니다. 'numpy.random'라는 이름의 package (module) 안에 있는 'rand', 'max' 등의 함수를 사용하고자 한다면 다음과 같이 입력해 준다.

# %%
import numpy
a = numpy.random.rand(6)
print(a)
numpy.ndarray.max(a)

import numpy as np

# %% [markdown]
# ## 가상 환경
#
# 기본적으로 가상 환경이 있는 가장 큰 이유는 "프로젝트를 위한 격리된 환경을 만드는 것"입니다. 쉽게 말해서 프로젝트마다 해당 프로젝트에 필요한 모듈만 담아서 만든 바구니라고 생각하시면 됩니다.
#
# Python을 포함하여 대부분의 프로그래밍 언어들은 패키지(또는 모듈)의 버전을 계속해서 최신화하고 있습니다. 이는 Python의 장점이기도 하지만 만약 특정 버전에서 일부 기능들은 없어지거나 새로 생기게 되는 경우 버전 충돌로 코드가 실행되지 않을 수 있습니다.
#
# 환경에는 패키지당 하나의 버전만 설치할 수 있기 때문에 해당 코르들 실행할 수 있는 패키지들의 의존성을 체크애야 합니다.
#
# 결론적으로는 가상환경은 작업을 바꿀 때마다 다른 버전의 라이브러리를 설치하는 불편함을 방지하기 위한 격리된 독립적인 환경을 만들어주는 역할을 합니다.

# %% [markdown]
# ### 가상 환경의 종류
#
# 가상환경의 종류도 매우 다양한데 venv는 Python 3.3 버전 이후부터 기본 모듈에 포함되어 있습니다.
#
# 저는 conda 가상환경을 주로 이용하는데 Anaconda Python을 설치했을 시 사용할 수 있는 모듈입니다.

# %% [markdown]
# ### conda 가상 환경
#
# conda 가상 환경에 사용할 수 있는 명령어들은 다음과 같다.
#
# * conda --version  # 아나콘다 버전 확인
# * conda create -n {환경명} python={버전}  # 가상환경 생성
# * conda env list # 가상환경 리스트 확인
# * conda remove -n {환경명} --all  # 가상환경 삭제
# * activate {환경명}  # 가상환경 on
# * deactivate 또는 conda deactivate  # 가상환경 off
# * conda config --set auto_activate_base false  # conda 자동활성화 off (자동으로 base 실행x)
# * conda config --set auto_activate_base True  # conda 자동활성화 on
# * conda env list > result.txt  # 가상환경 리스트를 result라는 txt파일로 저장하기
# * conda env export > {환경명}.yaml  # 가상환경 내보내기 (export)
# * conda env create -f {환경명}.yaml  # .yaml 파일로 새로운 가상환경 만들기
# * conda env update --file {환경명}.yaml # .yaml
# * conda env update --{환경명} envname --file {환경명}.yaml  ## .yaml 파일로 가상환경 업데이트(deactivate 되어있을 때)

# %% [markdown]
# ### VS code 에서 conda env
#
# 1. VS code 실행
# 2. Python 파일 선택
# 3. [ctrl] + [shift] + [p] 누르고, [Terminal : Select Default Profile] 선택, [Command prompt] 선택
# 4. [ctrl] + [shift] + [p] 누르고, [Python: select interpreter] 선택, 해당 anaconda env 선택

# %% [markdown]
# ## 주피터 노트북에서 module 설치

# %% [markdown]
# #### pip install
#
# 주피터 노트북에서는 pip와 관련된 아래의 쉘 명령어나 매직 코멘드로 설치할 수 있습니다. 구글 코랩에서도 같은 방법을 이용할 수 있습니다.
#
# > !pip install modulename
#
# > %pip install modulename

# %%
# !pip install pyhdf

# %%
# %pip install pyhdf

# %% [markdown]
# #### conda install
#
# 자신의 컴퓨터에서 anaconda가 설치되어 있는 경우라면  conda install도 가능한 것으로 확인되지만, 구글 코랩에서는 anaconda가 설치되어 있지 않기 때문에 conda install을 바로 사용할 수 없습니다.
#
# > !conda install modulename
#
# > %conda install modulename

# %%
# !conda install modulename # 구글 코랩에서는 사용할 수 없음.
# %conda install modulename # 구글 코랩에서는 사용할 수 없음.

# %% [markdown]
# 이제 설치가 되었으니 import가 될 것입니다.

# %%
import pyhdf

# %% [markdown]
# 간혹 pip로 설치가 되지 않는 경우에 해결책은 구글링하면 찾을 수 있을 것입니다.

# %% [markdown]
# ### 설치된 모듈 확인
#
# 아래의 셀은 설치된 모듈을 버전까지 쉽게 확인할 수 있도록 코딩한 것입니다.

# %%
import importlib, sys, subprocess
packages = "numpy, matplotlib, astropy, version_information" # required modules
pkgs = packages.split(", ")
for pkg in pkgs :
    if not importlib.util.find_spec(pkg):
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', pkg, '-q']) # pip install
        #subprocess.check_call([sys.executable, '-m', 'conda', 'install', pkg, ]) # conda install
        print(f"**** {pkg} module is now being installed.")
    else:
        print(f"******** {pkg} module is already installed.")
print("#"*60)
# %load_ext version_information
import time
now = time.strftime("%Y-%m-%d %H:%M:%S (%Z = GMT%z)")
print(f"This notebook was generated at {now} ")

vv = %version_information {packages}
for i, pkg in enumerate(vv.packages):
    print(f"{i} {pkg[0]:10s} {pkg[1]:s}")
