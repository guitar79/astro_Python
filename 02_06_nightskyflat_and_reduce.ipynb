# %% [markdown]
# # Nightsky flat

# %% [markdown]
# ## 필요한 모듈
#
# 이 프로젝트를 위해서는 아래의 모듈이 필요하다.
#
# > numpy, pandas, matplotlib, astropy, version_information

# %% [markdown]
# ### 모듈 설치
#
# 1. 콘솔 창에서 모듈을 설치할 때는 아래와 같은 형식으로 입력하면 된다.
#
# >pip install module_name==version
#
# >conda install module_name==version
#
# 2. 주피터 노트북(코랩 포함)에 설치 할 때는 아래의 셀을 실행해서 실행되지 않은 모듈을 설치할 수 있다. (pip 기준) 만약 아나콘다 환경을 사용한다면 7행을 콘다 설치 명령어에 맞게 수정하면 된다.

# %% [markdown]
# ### 모듈 버전 확인
#
# 아래 셀을 실행하면 이 노트북을 실행한 파이썬 및 관련 모듈의 버전을 확인할 수 있다.

# %%
import importlib, sys, subprocess
packages = "numpy, pandas, matplotlib, scipy, astropy, photutils, ccdproc, ysfitsutilpy, ysphotutilpy, version_information" # required modules
pkgs = packages.split(", ")
for pkg in pkgs :
    if not importlib.util.find_spec(pkg):
        print(f"**** module {pkg} is not installed... now start install")
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', pkg, '-q'])
        print(f"****** module {pkg} is installed")
    else: 
        print(f"**** module {pkg} is installed")

# %load_ext version_information
import time
now = time.strftime("%Y-%m-%d %H:%M:%S (%Z = GMT%z)")
print(f"This notebook was generated at {now} ")

vv = %version_information {packages}
for i, pkg in enumerate(vv.packages):
    print(f"{i} {pkg[0]:10s} {pkg[1]:s}")
# Out:
# **** module numpy is installed
# **** module pandas is installed
# **** module matplotlib is installed
# **** module scipy is installed
# **** module astropy is installed
# **** module photutils is installed
# **** module ccdproc is installed
# **** module ysfitsutilpy is installed
# **** module ysphotutilpy is installed
# **** module version_information is installed
# The version_information extension is already loaded. To reload it, use:
#   %reload_ext version_information
# This notebook was generated at 2024-07-03 20:43:47 (KST = GMT+0900)
# 0 Python     3.11.5 64bit [GCC 11.2.0]
# 1 IPython    8.25.0
# 2 OS         Linux 5.15.0 107 generic x86_64 with glibc2.31
# 3 numpy      1.26.4
# 4 pandas     2.2.2
# 5 matplotlib 3.8.4
# 6 scipy      1.12.0
# 7 astropy    6.1.0
# 8 photutils  1.9.0
# 9 ccdproc    2.4.2
# 10 ysfitsutilpy 0.2
# 11 ysphotutilpy 0.1.1
# 12 version_information 1.0.4

# %% [markdown]
# ### import modules

# %%
import os
from glob import glob
from astropy.nddata import CCDData
from pathlib import Path

import ysfitsutilpy as yfu
#import ysphotutilpy as ypu
#import ysvisutilpy as yvu

import _Python_utilities
import _astro_utilities

# %%
#%%
#######################################################
BASEDIR = Path("/mnt/Rdata/OBS_data") 
PROJECDIR = Path("/mnt/Rdata/OBS_data/2024-EXO")
TODODIR = PROJECDIR / "_-_-_2024-05_-_GSON300_STF-8300M_-_1bin"
TODODIR = PROJECDIR / "_-_-_2024-06_-_GSON300_STF-8300M_-_1bin"

PROJECDIR = Path("/mnt/Rdata/OBS_data/2022-Asteroid")
TODODIR = PROJECDIR / "GSON300_STF-8300M_-_1bin"
TODODIR = PROJECDIR / "RiLA600_STX-16803_-_1bin"
TODODIR = PROJECDIR / "RiLA600_STX-16803_-_2bin"

PROJECDIR = Path("/mnt/Rdata/OBS_data/2023-Asteroid")
TODODIR = PROJECDIR / "GSON300_STF-8300M_-_1bin"
# TODODIR = PROJECDIR / "RiLA600_STX-16803_-_1bin"
# TODODIR = PROJECDIR / "RiLA600_STX-16803_-_2bin"

# PROJECDIR = Path("/mnt/Rdata/OBS_data/2016-Variable")
# TODODIR = PROJECDIR / "-_-_-_2016-_-_RiLA600_STX-16803_-_2bin"

# PROJECDIR = Path("/mnt/Rdata/OBS_data/2017-Variable")
# TODODIR = PROJECDIR / "-_-_-_2017-_-_RiLA600_STX-16803_-_2bin"

DOINGDIRs = sorted(_Python_utilities.getFullnameListOfsubDirs(TODODIR))
print ("DOINGDIRs: ", format(DOINGDIRs))
print ("len(DOINGDIRs): ", format(len(DOINGDIRs)))

CALDIR = [x for x in DOINGDIRs if "CAL-BDF" in str(x)]
MASTERDIR = Path(CALDIR[0]) / _astro_utilities.master_dir
if not MASTERDIR.exists():
    os.makedirs("{}".format(str(MASTERDIR)))
    print("{} is created...".format(str(MASTERDIR)))

print ("MASTERDIR: ", format(MASTERDIR))

DOINGDIRs = sorted([x for x in DOINGDIRs if "_LIGHT_" in str(x)])
print ("DOINGDIRs: ", format(DOINGDIRs))
print ("len(DOINGDIRs): ", format(len(DOINGDIRs)))

filter_str = '498TOKIO_LIGHT_-_2023-11-24_-_GSON300_STF-8300M_-_1bin'
DOINGDIRs = [x for x in DOINGDIRs if filter_str in str(x)]
# remove = 'BIAS'
# DOINGDIRs = [x for x in DOINGDIRs if remove not in x]
# remove = 'DARK'
# DOINGDIRs = [x for x in DOINGDIRs if remove not in x]
# remove = 'FLAT'
# DOINGDIRs = [x for x in DOINGDIRs if remove not in x]
print ("DOINGDIRs: ", DOINGDIRs)
print ("len(DOINGDIRs): ", len(DOINGDIRs))
#######################################################
# Out:
# DOINGDIRs:  ['/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/120LACHESIS_LIGHT_-_2023-10-09_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/120LACHESIS_LIGHT_-_2023-10-10_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/120LACHESIS_LIGHT_-_2023-10-16_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/120LACHESIS_LIGHT_-_2023-11-14_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/1266TONE_LIGHT_-_2023-11-21_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/127JOHANNA_LIGHT_-_2023-11-17_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/127JOHANNA_LIGHT_-_2023-11-24_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/127JOHANNA_LIGHT_-_2023-12-03_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/128NEMESIS_LIGHT_-_2023-12-01_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/132AETHRA_LIGHT_-_2023-11-24_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/132AETHRA_LIGHT_-_2023-12-03_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/135HERTHA_LIGHT_-_2023-10-09_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/135HERTHA_LIGHT_-_2023-10-10_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/135HERTHA_LIGHT_-_2023-10-16_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/135HERTHA_LIGHT_-_2023-11-17_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/1659PUNKAHARJU_LIGHT_-_2023-10-11_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/1659PUNKAHARJU_LIGHT_-_2023-10-16_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/1659PUNKAHARJU_LIGHT_-_2023-10-17_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/182ELSA_LIGHT_-_2023-11-07_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/198AMPELLA_LIGHT_-_2022-09-06_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/21LUTETIA_LIGHT_-_2023-10-16_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/21LUTETIA_LIGHT_-_2023-11-24_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/239ADRASTEA_LIGHT_-_2023-12-22_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/241GERMANIA_LIGHT_-_2023-11-07_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/241GERMANIA_LIGHT_-_2023-11-19_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/241GERMANIA_LIGHT_-_2023-11-20_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/293BRASILIA_LIGHT_-_2023-12-12_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/300GERALDINA_LIGHT_-_2023-12-22_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/306UNITAS_LIGHT_-_2023-12-01_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/306UNITAS_LIGHT_-_2023-12-03_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/317ROXANE_LIGHT_-_2023-11-21_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/345TERCIDINA_LIGHT_-_2023-10-11_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/345TERCIDINA_LIGHT_-_2023-10-16_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_ ...
# len(DOINGDIRs):  92
# MASTERDIR:  /mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/CAL-BDF_-_-_2023_-_GSON300_STF-8300M_-_1bin/master_files_ys
# DOINGDIRs:  ['/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/120LACHESIS_LIGHT_-_2023-10-09_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/120LACHESIS_LIGHT_-_2023-10-10_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/120LACHESIS_LIGHT_-_2023-10-16_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/120LACHESIS_LIGHT_-_2023-11-14_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/1266TONE_LIGHT_-_2023-11-21_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/127JOHANNA_LIGHT_-_2023-11-17_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/127JOHANNA_LIGHT_-_2023-11-24_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/127JOHANNA_LIGHT_-_2023-12-03_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/128NEMESIS_LIGHT_-_2023-12-01_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/132AETHRA_LIGHT_-_2023-11-24_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/132AETHRA_LIGHT_-_2023-12-03_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/135HERTHA_LIGHT_-_2023-10-09_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/135HERTHA_LIGHT_-_2023-10-10_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/135HERTHA_LIGHT_-_2023-10-16_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/135HERTHA_LIGHT_-_2023-11-17_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/1659PUNKAHARJU_LIGHT_-_2023-10-11_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/1659PUNKAHARJU_LIGHT_-_2023-10-16_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/1659PUNKAHARJU_LIGHT_-_2023-10-17_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/182ELSA_LIGHT_-_2023-11-07_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/198AMPELLA_LIGHT_-_2022-09-06_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/21LUTETIA_LIGHT_-_2023-10-16_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/21LUTETIA_LIGHT_-_2023-11-24_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/239ADRASTEA_LIGHT_-_2023-12-22_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/241GERMANIA_LIGHT_-_2023-11-07_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/241GERMANIA_LIGHT_-_2023-11-19_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/241GERMANIA_LIGHT_-_2023-11-20_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/293BRASILIA_LIGHT_-_2023-12-12_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/300GERALDINA_LIGHT_-_2023-12-22_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/306UNITAS_LIGHT_-_2023-12-01_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/306UNITAS_LIGHT_-_2023-12-03_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/317ROXANE_LIGHT_-_2023-11-21_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/345TERCIDINA_LIGHT_-_2023-10-11_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/345TERCIDINA_LIGHT_-_2023-10-16_-_GSON300_STF-8300M_-_1bin/', '/mnt/Rdata/OBS_ ...
# len(DOINGDIRs):  91
# DOINGDIRs:  ['/mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/498TOKIO_LIGHT_-_2023-11-24_-_GSON300_STF-8300M_-_1bin/']
# len(DOINGDIRs):  1

# %%
for DOINGDIR in DOINGDIRs[:] :
    
    DOINGDIR = Path(DOINGDIR)
    print (DOINGDIR.parts[-1])
    sMASTERDIR = DOINGDIR / _astro_utilities.master_dir
    REDUCEDDIR = DOINGDIR / _astro_utilities.reduced_dir
    REDUC_nightsky = DOINGDIR / _astro_utilities.reduced_nightsky_dir

    # if not MASTERDIR.exists():
    # shutil.copytree(MASTERDIR, MASTERDIR, dirs_exist_ok=True)

    if not sMASTERDIR.exists():
        os.makedirs(str(sMASTERDIR))
        print("{} is created...".format(str(sMASTERDIR)))

    if not REDUC_nightsky.exists():
        os.makedirs("{}".format(str(REDUC_nightsky)))
        print("{} is created...".format(str(REDUC_nightsky)))
    
    summary = yfu.make_summary(DOINGDIR/"*.fit*")
    if summary is not None :
        print("len(summary):", len(summary))
        print("summary:", summary)
        #print(summary["file"][0])   

        summary_light = summary.loc[summary["IMAGETYP"] == "LIGHT"].copy()
        summary_light = summary_light.reset_index(drop=True) 

        for filt in ["b", "v", "r", "L", "R", "G", "B"]:
        #for filt in ["V"]:
            summary_light_filt = summary_light.loc[summary_light["FILTER"] == filt].copy()
            
            if summary_light_filt.empty:
                print("The dataframe(summary_light_filt) is empty")
                pass
            else:
                try:
                    if (not (sMASTERDIR / f"nightskyflat-{filt}.fits").exists()) :
                        print("len(summary_light_filt):", len(summary_light_filt))
                        print("summary_light_filt:", summary_light_filt)
                        
                        File_Num = 80
                        if len(summary_light_filt["file"]) > File_Num :
                            combine_lst = summary_light_filt["file"].tolist()[:File_Num]
                        else : 
                            combine_lst = summary_light_filt["file"].tolist()
                        ccd = yfu.imcombine(
                            combine_lst, 
                            combine="med",
                            scale="avg", 
                            scale_to_0th=False, 
                            reject="sc", 
                            sigma=2.5,
                            verbose=True,
                            memlimit = 2.e+11,
                            )
                        ccd.write(sMASTERDIR / f"nightskyflat-{filt}.fits", overwrite=True)
                except Exception as err: 
                    print ('Error messgae .......')
                    #_Python_utilities.write_log(err_log_file, err)

        for _, row in summary_light.iterrows():
            try: 
                fpath = Path(row["file"])
                filt = row["FILTER"]
                if (not (REDUC_nightsky/fpath.name).exists()) :
                    ccd = yfu.ccdred(
                        fpath, 
                        mflatpath=str(sMASTERDIR / f"nightskyflat-{filt}.fits"),
                        output=REDUC_nightsky/fpath.name,
                        )
            except FileNotFoundError: 
                # _Python_utilities.write_log(err_log_file, "FileNotFoundError")
                print("FileNotFoundError")
# Out:
# 498TOKIO_LIGHT_-_2023-11-24_-_GSON300_STF-8300M_-_1bin
# /mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/498TOKIO_LIGHT_-_2023-11-24_-_GSON300_STF-8300M_-_1bin/master_files_ys is created...
# /mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/498TOKIO_LIGHT_-_2023-11-24_-_GSON300_STF-8300M_-_1bin/REDUC_nightsky is created...
# All 53 keywords (guessed from /mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-8300M_-_1bin/498TOKIO_LIGHT_-_2023-11-24_-_GSON300_STF-8300M_-_1bin/498TOKIO_LIGHT_B_2023-11-24-19-55-02_300sec_GSON300_STF-8300M_-30c_1bin.fit) will be loaded.
# len(summary): 5
# summary:                                                 file  filesize  SIMPLE  \
# 0  /mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-...  16980480    True
# 1  /mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-...  16980480    True
# 2  /mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-...  16980480    True
# 3  /mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-...  16980480    True
# 4  /mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-...  16980480    True
#
#    BITPIX  NAXIS  NAXIS1  NAXIS2  EXTEND  BZERO IMAGETYP  ...  FOCTEMP  \
# 0      16      2    3352    2532    True  32768    LIGHT  ...  -0.8750
# 1      16      2    3352    2532    True  32768    LIGHT  ...  -1.0625
# 2      16      2    3352    2532    True  32768    LIGHT  ...  -1.2500
# 3      16      2    3352    2532    True  32768    LIGHT  ...  -1.4375
# 4      16      2    3352    2532    True  32768    LIGHT  ...  -0.8750
#
#    FOCUSTEM  ROWORDER EQUINOX                   SWCREATE    CCDNAME    OPTIC  \
# 0   -0.8750  TOP-DOWN  2000.0  N.I.N.A. 2.3.2.9001 (x64)  STF-8300M  GSON300
# 1   -1.0625  TOP-DOWN  2000.0  N.I.N.A. 2.3.2.9001 (x64)  STF-8300M  GSON300
# 2   -1.2500  TOP-DOWN  2000.0  N.I.N.A. 2.3.2.9001 (x64)  STF-8300M  GSON300
# 3   -1.4375  TOP-DOWN  2000.0  N.I.N.A. 2.3.2.9001 (x64)  STF-8300M  GSON300
# 4   -0.8750  TOP-DOWN  2000.0  N.I.N.A. 2.3.2.9001 (x64)  STF-8300M  GSON300
#
#    APATURE  PIXSCALE  FLIPSTAT
# 0      300  0.928193
# 1      300  0.928193
# 2      300  0.928193
# 3      300  0.928193
# 4      300  0.928193
#
# [5 rows x 55 columns]
# The dataframe(summary_light_filt) is empty
# The dataframe(summary_light_filt) is empty
# The dataframe(summary_light_filt) is empty
# The dataframe(summary_light_filt) is empty
# len(summary_light_filt): 3
# summary_light_filt:                                                 file  filesize  SIMPLE  \
# 2  /mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-...  16980480    True
# 3  /mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-...  16980480    True
# 4  /mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-...  16980480    True
#
#    BITPIX  NAXIS  NAXIS1  NAXIS2  EXTEND  BZERO IMAGETYP  ...  FOCTEMP  \
# 2      16      2    3352    2532    True  32768    LIGHT  ...  -1.2500
# 3      16      2    3352    2532    True  32768    LIGHT  ...  -1.4375
# 4      16      2    3352    2532    True  32768    LIGHT  ...  -0.8750
#
#    FOCUSTEM  ROWORDER EQUINOX                   SWCREATE    CCDNAME    OPTIC  \
# 2   -1.2500  TOP-DOWN  2000.0  N.I.N.A. 2.3.2.9001 (x64)  STF-8300M  GSON300
# 3   -1.4375  TOP-DOWN  2000.0  N.I.N.A. 2.3.2.9001 (x64)  STF-8300M  GSON300
# 4   -0.8750  TOP-DOWN  2000.0  N.I.N.A. 2.3.2.9001 (x64)  STF-8300M  GSON300
#
#    APATURE  PIXSCALE  FLIPSTAT
# 2      300  0.928193
# 3      300  0.928193
# 4      300  0.928193
#
# [3 rows x 55 columns]
# 2024-07-03 11:43:47.563
# - Organizing... Done.
# - Loading, calculating offsets with zero/scale...
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60272.826907 from DATE-OBS.
# Set MJD-AVG to 60272.828125 from DATE-AVG'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60272.833616 from DATE-OBS.
# Set MJD-AVG to 60272.834835 from DATE-AVG'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60272.840362 from DATE-OBS.
# Set MJD-AVG to 60272.841581 from DATE-AVG'. [astropy.wcs.wcs]
# Done.
# HISTORY  Loaded 3 FITS, calculated zero, scale, weights
# HISTORY  ..................................(dt = 1.346 s) 2024-07-03T11:43:50.534
# - Rejection
# -- reject='sigclip' (irafmode=True)
# --       params: nkeep=1, maxrej=3, maxiters=50, cenfunc='median'
#   (for sigclip): sigma=2.5, ddof=1
# Done.
# - Combining
# -- combine = med
# Done.
# HISTORY  Rejection and combination done
# HISTORY  ..................................(dt = 1.322 s) 2024-07-03T11:43:51.857
#
# - Writing output FITS... Done.
#
# 2024-07-03 11:43:51.862 (TOTAL dt =   4.3 sec)
# The dataframe(summary_light_filt) is empty
# len(summary_light_filt): 2
# summary_light_filt:                                                 file  filesize  SIMPLE  \
# 0  /mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-...  16980480    True
# 1  /mnt/Rdata/OBS_data/2023-Asteroid/GSON300_STF-...  16980480    True
#
#    BITPIX  NAXIS  NAXIS1  NAXIS2  EXTEND  BZERO IMAGETYP  ...  FOCTEMP  \
# 0      16      2    3352    2532    True  32768    LIGHT  ...  -0.8750
# 1      16      2    3352    2532    True  32768    LIGHT  ...  -1.0625
#
#    FOCUSTEM  ROWORDER EQUINOX                   SWCREATE    CCDNAME    OPTIC  \
# 0   -0.8750  TOP-DOWN  2000.0  N.I.N.A. 2.3.2.9001 (x64)  STF-8300M  GSON300
# 1   -1.0625  TOP-DOWN  2000.0  N.I.N.A. 2.3.2.9001 (x64)  STF-8300M  GSON300
#
#    APATURE  PIXSCALE  FLIPSTAT
# 0      300  0.928193
# 1      300  0.928193
#
# [2 rows x 55 columns]
# 2024-07-03 11:43:51.936
# - Organizing... Done.
# - Loading, calculating offsets with zero/scale... Done.
# HISTORY  Loaded 2 FITS, calculated zero, scale, weights
# HISTORY  ..................................(dt = 0.067 s) 2024-07-03T11:43:53.480
# - Rejection
# -- reject='sigclip' (irafmode=True)
# --       params: nkeep=1, maxrej=2, maxiters=50, cenfunc='median'
#   (for sigclip): sigma=2.5, ddof=1
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60272.829888 from DATE-OBS.
# Set MJD-AVG to 60272.831628 from DATE-AVG'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60272.836395 from DATE-OBS.
# Set MJD-AVG to 60272.838135 from DATE-AVG'. [astropy.wcs.wcs]
# Done.
# - Combining
# -- combine = med
# Done.
# HISTORY  Rejection and combination done
# HISTORY  ..................................(dt = 0.875 s) 2024-07-03T11:43:54.355
#
# - Writing output FITS... Done.
#
# 2024-07-03 11:43:54.360 (TOTAL dt =  2.42 sec)
# FileNotFoundError
# FileNotFoundError
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60272.826907 from DATE-OBS.
# Set MJD-AVG to 60272.828125 from DATE-AVG'. [astropy.wcs.wcs]
# FileNotFoundError
# FileNotFoundError
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60272.833616 from DATE-OBS.
# Set MJD-AVG to 60272.834835 from DATE-AVG'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60272.840362 from DATE-OBS.
# Set MJD-AVG to 60272.841581 from DATE-AVG'. [astropy.wcs.wcs]
# FileNotFoundError

# %% [markdown]
# ### Light
