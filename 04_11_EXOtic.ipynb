# %% [markdown]
# 02_10_EXOtic

# %% [markdown]
# ## 필요한 모듈
#
# 이 프로젝트를 위해서는 아래의 모듈이 필요하다.
#
# > numpy, pandas, matplotlib, scipy, astropy, astroquery, photutils,  exotic, ccdproc, version_information

# %% [markdown]
# ### 모듈 설치
#
# 1. 콘솔 창에서 모듈을 설치할 때는 아래와 같은 형식으로 입력하면 된다.
#
# >pip install module_name==version
#
# >conda install module_name=version
#
# 2. 주피터 노트북(코랩 포함)에 설치 할 때는 아래의 셀을 실행해서 실행되지 않은 모듈을 설치할 수 있다. (pip 기준) 만약 아나콘다 환경을 사용한다면 7행을 콘다 설치 명령어에 맞게 수정하면 된다.

# %% [markdown]
# ### 모듈 버전 확인
#
# 아래 셀을 실행하면 이 노트북을 실행한 파이썬 및 관련 모듈의 버전을 확인할 수 있다.

# %%
# import importlib, sys, subprocess
# packages = "numpy, pandas, matplotlib, scipy, astropy, astroquery, photutils, ysfitsutilpy, ysphotutilpy, ccdproc, aplpy, sncosmo, version_information" # required modules
# pkgs = packages.split(", ")
# for pkg in pkgs :
#     if not importlib.util.find_spec(pkg):
#         print(f"**** module {pkg} is being installed")
#         subprocess.check_call([sys.executable, '-m', 'pip', 'install', pkg, '-q'])
#     else: 
#         print(f"**** module {pkg} is installed")

# %load_ext version_information
# import time
# now = time.strftime("%Y-%m-%d %H:%M:%S (%Z = GMT%z)")
# print(f"This notebook was generated at {now} ")

# vv = %version_information {packages}
# for i, pkg in enumerate(vv.packages):
#     print(f"{i} {pkg[0]:10s} {pkg[1]:s}")
# Out:
# **** module numpy is installed
# **** module pandas is installed
# **** module matplotlib is installed
# **** module scipy is installed
# **** module astropy is installed
# **** module astroquery is installed
# **** module photutils is installed
# **** module ysfitsutilpy is installed
# **** module ysphotutilpy is installed
# **** module ccdproc is installed
# **** module aplpy is installed
# **** module sncosmo is installed
# **** module version_information is installed
# This notebook was generated at 2024-07-15 22:46:36 (KST = GMT+0900)
# 0 Python     3.12.3 64bit [GCC 11.2.0]
# 1 IPython    8.25.0
# 2 OS         Linux 5.15.0 113 generic x86_64 with glibc2.31
# 3 numpy      1.26.4
# 4 pandas     2.2.2
# 5 matplotlib 3.8.4
# 6 scipy      1.13.1
# 7 astropy    6.1.0
# 8 astroquery 0.4.7
# 9 photutils  1.12.0
# 10 ysfitsutilpy 0.2
# 11 ysphotutilpy 0.1.1
# 12 ccdproc    2.4.2
# 13 aplpy      2.1.0
# 14 sncosmo    2.10.4
# 15 version_information 1.0.4

# %% [markdown]
# ### import modules

# %%
# #%%
# from glob import glob
# from pathlib import Path
# import os
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt

# from ccdproc import combine, ccd_process, CCDData

# from astropy.io import fits
# from astropy.wcs import WCS
# from astropy import units as u
# from astropy.wcs import WCS
# from astropy.time import Time
# from astropy.coordinates import SkyCoord, EarthLocation, AltAz

# import astropy.units as u

# import ysfitsutilpy as yfu
# import ysphotutilpy as ypu

# import _astro_utilities
# import _Python_utilities
# import _tool_visualization

# %%
import bokeh.io
# from exotic.api.plotting import plot_image
from exotic.exotic import NASAExoplanetArchive, get_wcs, find_target
from astropy.time import Time
from barycorrpy import utc_tdb
import numpy as np
from io import BytesIO
from astropy.io import fits
from scipy.ndimage import label
from bokeh.plotting import figure, output_file, show
from bokeh.palettes import Viridis256
from bokeh.models import ColorBar, LinearColorMapper, LogColorMapper, LogTicker
from bokeh.models import BoxZoomTool,WheelZoomTool,ResetTool,HoverTool,PanTool,FreehandDrawTool
from bokeh.io import output_notebook
from bokeh.layouts import row
from pprint import pprint
from IPython.display import Image
from ipywidgets import widgets, HBox
from skimage.transform import rescale, resize, downscale_local_mean
import copy
import matplotlib.pyplot as plt

import dynesty
from dynesty import plotting
from dynesty.utils import resample_equal
from scipy.stats import gaussian_kde
import os
import re
import json
import subprocess

# %%
# import ysfitsutilpy as yfu
# import ysphotutilpy as ypu
from pathlib import Path

import _astro_utilities
import _Python_utilities
import _tool_visualization

# %%
#%%
#######################################################
BASEDIR = Path("/mnt/Rdata/ASTRO_data") 
PROJECDIR = Path("/mnt/Rdata/ASTRO_data/2024-EXO")
TODODIR = PROJECDIR / "_-_-_2024-05_-_GSON300_STF-8300M_-_1bin"
TODODIR = PROJECDIR / "_-_-_2024-06_-_GSON300_STF-8300M_-_1bin"
TODODIR = PROJECDIR / "RiLA600_STX-16803_-_1bin"
TODODIR = PROJECDIR / "RiLA600_STX-16803_-_2bin"

# PROJECDIR = Path("/mnt/Rdata/ASTRO_data/2022-Asteroid")
# TODODIR = PROJECDIR / "GSON300_STF-8300M_-_1bin"
# TODODIR = PROJECDIR / "RiLA600_STX-16803_-_1bin"
# TODODIR = PROJECDIR / "RiLA600_STX-16803_-_2bin"

# PROJECDIR = Path("/mnt/Rdata/ASTRO_data/2023-Asteroid")
# TODODIR = PROJECDIR / "GSON300_STF-8300M_-_1bin"
# TODODIR = PROJECDIR / "RiLA600_STX-16803_-_1bin"
# TODODIR = PROJECDIR / "RiLA600_STX-16803_-_2bin"

# PROJECDIR = Path("/mnt/Rdata/ASTRO_data/2016-Variable")
# TODODIR = PROJECDIR / "-_-_-_2016-_-_RiLA600_STX-16803_-_2bin"

# PROJECDIR = Path("/mnt/Rdata/ASTRO_data/2017-Variable")
# TODODIR = PROJECDIR / "-_-_-_2017-_-_RiLA600_STX-16803_-_2bin"

DOINGDIRs = sorted(_Python_utilities.getFullnameListOfsubDirs(TODODIR))
print ("DOINGDIRs: ", format(DOINGDIRs))
print ("len(DOINGDIRs): ", format(len(DOINGDIRs)))

BDFDIR = [x for x in DOINGDIRs if "CAL-BDF" in str(x)]
MASTERDIR = Path(BDFDIR[0]) / _astro_utilities.master_dir
if not MASTERDIR.exists():
    os.makedirs("{}".format(str(MASTERDIR)))
    print("{} is created...".format(str(MASTERDIR)))

print ("MASTERDIR: ", format(MASTERDIR))

DOINGDIRs = sorted([x for x in DOINGDIRs if "_LIGHT_" in str(x)])
print ("DOINGDIRs: ", format(DOINGDIRs))
print ("len(DOINGDIRs): ", format(len(DOINGDIRs)))

# filter_str = '2023-12-'
# DOINGDIRs = [x for x in DOINGDIRs if filter_str in x]
# remove = 'BIAS'
# DOINGDIRs = [x for x in DOINGDIRs if remove not in x]
# remove = 'DARK'
# DOINGDIRs = [x for x in DOINGDIRs if remove not in x]
# remove = 'FLAT'
# DOINGDIRs = [x for x in DOINGDIRs if remove not in x]
print ("DOINGDIRs: ", DOINGDIRs)
print ("len(DOINGDIRs): ", len(DOINGDIRs))
#######################################################
# Out:
# DOINGDIRs:  ['/mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/-_CAL-BDF_-_2024-05_-_-_STX-16803_-_2bin/', '/mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/', '/mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HD189733b_LIGHT_-_2024-06-27_-_RiLA600_STX-16803_-_2bin/', '/mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/Kepler-17b_LIGHT_-_2024-06-26_-_RiLA600_STX-16803_-_2bin/', '/mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/TrES-1b_LIGHT_-_2024-06-09_-_RiLA600_STX-16803_-_2bin/', '/mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/TrES-1b_LIGHT_-_2024-06-18_-_RiLA600_STX-16803_-_2bin/', '/mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/TrES-4b_LIGHT_-_2024-06-13_-_RiLA600_STX-16803_-_2bin/', '/mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/WASP-103b_LIGHT_-_2024-06-06_-_RiLA600_STX-16803_-_2bin/']
# len(DOINGDIRs):  8
# MASTERDIR:  /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/-_CAL-BDF_-_2024-05_-_-_STX-16803_-_2bin/master_files_ys
# DOINGDIRs:  ['/mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/', '/mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HD189733b_LIGHT_-_2024-06-27_-_RiLA600_STX-16803_-_2bin/', '/mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/Kepler-17b_LIGHT_-_2024-06-26_-_RiLA600_STX-16803_-_2bin/', '/mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/TrES-1b_LIGHT_-_2024-06-09_-_RiLA600_STX-16803_-_2bin/', '/mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/TrES-1b_LIGHT_-_2024-06-18_-_RiLA600_STX-16803_-_2bin/', '/mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/TrES-4b_LIGHT_-_2024-06-13_-_RiLA600_STX-16803_-_2bin/', '/mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/WASP-103b_LIGHT_-_2024-06-06_-_RiLA600_STX-16803_-_2bin/']
# len(DOINGDIRs):  7
# DOINGDIRs:  ['/mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/', '/mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HD189733b_LIGHT_-_2024-06-27_-_RiLA600_STX-16803_-_2bin/', '/mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/Kepler-17b_LIGHT_-_2024-06-26_-_RiLA600_STX-16803_-_2bin/', '/mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/TrES-1b_LIGHT_-_2024-06-09_-_RiLA600_STX-16803_-_2bin/', '/mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/TrES-1b_LIGHT_-_2024-06-18_-_RiLA600_STX-16803_-_2bin/', '/mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/TrES-4b_LIGHT_-_2024-06-13_-_RiLA600_STX-16803_-_2bin/', '/mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/WASP-103b_LIGHT_-_2024-06-06_-_RiLA600_STX-16803_-_2bin/']
# len(DOINGDIRs):  7

# %%
# DOINGDIRs = DOINGDIRs[1:2]
# print("DOINGDIRs:", DOINGDIRs)
# Out:
# DOINGDIRs: [PosixPath('/mnt/Rdata/ASTRO_data/2024-EXO/GSON300_STF-8300M_-_1bin/Qatar-1b_LIGHT_-_2024-05-29_-_GSON300_STF-8300M_-_1bin')]

# %%
#####################################################################
# Observed location
LOCATION = dict(lon=127.005, lat=37.308889, elevation=101)
Suwon =  EarthLocation(lon=127.005 * u.deg, 
                                 lat=37.308889 * u.deg, 
                                 height=101 * u.m)
observatory_code = "P64"

# Used for any `astropy.SkyCoord` object:
SKYC_KW = dict(unit=u.deg, frame='icrs')

#######################################################
# Initial guess of FWHM in pixel
FWHM_INIT = 6

# Photometry parameters
R_AP = 1.5*FWHM_INIT # Aperture radius
R_IN = 4*FWHM_INIT   # Inner radius of annulus
R_OUT = 6*FWHM_INIT  # Outer radius of annulus

Mag_Low = 11.5
Mag_High = 15

Mag_target = 12.5
Mag_delta = 2
ERR_Max = 0.5
#######################################################

# %%
for DOINGDIR in DOINGDIRs[:1] :
    DOINGDIR = Path(DOINGDIR)
    print("DOINGDIR", DOINGDIR)

    READINGDIR = DOINGDIR / _astro_utilities.reduced_dir
    READINGDIR = DOINGDIR / _astro_utilities.reduced_nightsky_dir

    DIFFPRESULTDIR = DOINGDIR / f"{READINGDIR.parts[-1]}_DPhot_Mag{Mag_target}"

    # print(str(DOINGDIR.parts[-2]) == "RiLA600_STX-16803_-_1bin")
    # if str(DOINGDIR.parts[-2]) == "RiLA600_STX-16803_-_1bin" :
    #     DOINGDIR = DOINGDIR / _astro_utilities.reduced_nightsky_dir
    # print(str(DOINGDIR.parts[-2]) == "GSON300_STF-8300M_-_1bin")
    # if str(DOINGDIR.parts[-2]) == "GSON300_STF-8300M_-_1bin" :
    #     DOINGDIR = DOINGDIR / _astro_utilities.reduced_dir

    # if not INSTRESULTDIR.exists():
    #     os.makedirs("{}".format(str(INSTRESULTDIR)))
    #     print("{} is created...".format(str(INSTRESULTDIR)))
    
    csv_in_dir = sorted(list(DIFFPRESULTDIR.glob('*result_photometry.csv')))
    #print("fits_in_dir", fits_in_dir)
    print("len(fits_in_dir)", len(csv_in_dir))
# Out:
# DOINGDIR /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin
# len(fits_in_dir) 105

# %%
df = pd.DataFrame()
for fpath in csv_in_dir[:]:
    fpath = Path(fpath)
    print(f"starting... {fpath}")
    df_csv = pd.read_csv(fpath)
    df = pd.concat([df, df_csv], axis=0)
# Out:
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-12-19-58_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-12-27-02_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-12-34-07_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-12-41-11_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-12-48-15_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-12-55-20_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-13-02-24_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-13-09-28_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-13-16-32_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-13-23-36_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-13-30-41_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-13-37-45_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-13-44-49_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-13-51-54_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-13-58-58_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-14-06-02_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-14-13-06_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-14-20-10_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-14-27-15_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-14-34-19_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-14-41-23_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-14-48-27_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-14-55-32_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-15-02-36_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-15-09-40_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-15-16-45_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-15-23-49_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-15-30-53_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-15-37-58_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-15-45-02_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-15-52-06_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-15-59-11_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-16-06-15_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-16-13-20_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-16-20-24_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-16-27-28_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-16-34-33_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-16-41-37_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-16-48-41_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-16-55-47_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-17-02-51_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-17-09-56_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-17-17-00_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-17-24-05_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-17-31-09_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-17-38-14_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-17-45-19_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-17-52-23_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-17-59-28_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-18-06-33_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-18-13-37_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-18-20-42_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-18-27-47_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-18-34-51_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-18-41-56_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-18-49-00_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-18-56-05_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-19-03-09_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-19-10-14_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-19-17-18_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_R_2024-06-28-19-24-23_210sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-12-16-47_180sec_RiLA600_STX-16803_-15c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-12-23-51_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-12-30-55_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-12-38-00_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-12-45-04_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-12-52-09_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-12-59-13_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-13-06-17_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-13-13-21_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-13-20-25_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-13-27-30_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-13-34-34_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-13-41-38_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-13-48-43_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-14-02-51_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-14-24-04_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-14-38-12_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-14-45-16_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-15-06-29_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-15-20-38_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-15-27-42_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-15-41-51_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-15-48-55_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-16-03-04_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-16-10-08_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-16-24-17_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-16-38-26_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-16-45-30_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-16-52-35_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-16-59-40_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-17-06-45_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-17-13-49_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-17-20-54_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-17-27-58_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-17-42-08_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-17-49-12_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-18-03-21_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-18-10-26_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-18-24-36_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-18-31-40_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-18-45-49_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-18-59-58_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-19-14-07_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv
# starting... /mnt/Rdata/ASTRO_data/2024-EXO/RiLA600_STX-16803_-_2bin/HAT-P-37b_LIGHT_-_2024-06-28_-_RiLA600_STX-16803_-_2bin/reduced_nightsky_DPhot_Mag12.5/HAT-P-37b_LIGHT_V_2024-06-28-19-21-11_180sec_RiLA600_STX-16803_-17c_2bin_result_photometry.csv

# %%
df_csv
# Out:
#      Unnamed: 0   id      xcenter      ycenter  aperture_sum          msky  \
# 0             0    1    54.532263    42.984030  6.068693e+06  23088.334612
# 1             1    2  1266.509148    42.833161  6.202427e+06  24027.977498
# 2             2    3  1675.860845    44.888568  6.174492e+06  24128.417626
# 3             3    4  2015.060216    46.339962  6.372913e+06  24163.505846
# 4             4    5   635.846039    53.504670  6.212310e+06  24009.747070
# ..          ...  ...          ...          ...           ...           ...
# 171         171  172   830.401771  2454.124258  6.042310e+06  23500.699934
# 172         172  173   482.471091  2455.521530  6.010676e+06  23268.075507
# 173         173  174  1734.294233  2459.199434  6.080307e+06  23484.584057
# 174         174  175    88.835449  2489.590498  5.863757e+06  22635.355632
# 175         175  176  3021.435846  2515.959032  6.896408e+06  23722.301790
#
#         sky_std    nsky  nrej      flux_star  ...  merr_ann     RAJ2000  \
# 0    278.537953  2245.0  13.0  193427.922668  ...  0.009005  304.374035
# 1    271.722451  2258.0   8.0   88051.377805  ...  0.019909  303.629452
# 2    271.075777  2251.0  10.0   34557.396113  ...  0.050621  303.378175
# 3    280.159245  2250.0   7.0  224049.572726  ...  0.007947  303.170041
# 4    271.308481  2259.0   8.0  102573.065857  ...  0.017099  304.016937
# ..          ...     ...   ...            ...  ...       ...         ...
# 171  258.522950  2254.0  10.0   62109.831073  ...  0.027753  303.926070
# 172  266.652323  2252.0   6.0   89672.310852  ...  0.019243  304.135037
# 173  267.819557  2234.0  27.0  104207.884788  ...  0.016658  303.383590
# 174  268.511135  2256.0   8.0  103760.401921  ...  0.016462  304.371739
# 175  282.040862  1524.0   3.0  859817.909875  ...  0.002200  302.613198
#
#        DEJ2000                                           filename  \
# 0    65.493486  Qatar-1b_LIGHT_V_2024-05-29-14-57-34_180sec_GS...
# 1    65.487922  Qatar-1b_LIGHT_V_2024-05-29-14-57-34_180sec_GS...
# 2    65.484689  Qatar-1b_LIGHT_V_2024-05-29-14-57-34_180sec_GS...
# 3    65.481764  Qatar-1b_LIGHT_V_2024-05-29-14-57-34_180sec_GS...
# 4    65.488569  Qatar-1b_LIGHT_V_2024-05-29-14-57-34_180sec_GS...
# ..         ...                                                ...
# 171  64.875734  Qatar-1b_LIGHT_V_2024-05-29-14-57-34_180sec_GS...
# 172  64.876892  Qatar-1b_LIGHT_V_2024-05-29-14-57-34_180sec_GS...
# 173  64.869151  Qatar-1b_LIGHT_V_2024-05-29-14-57-34_180sec_GS...
# 174  64.869568  Qatar-1b_LIGHT_V_2024-05-29-14-57-34_180sec_GS...
# 175  64.843801  Qatar-1b_LIGHT_V_2024-05-29-14-57-34_180sec_GS...
#
#                      t_start t_expos                 t_middle  filter  \
# 0    2024-05-29T14:57:34.789   180.0  2024-05-29T14:59:04.789       V
# 1    2024-05-29T14:57:34.789   180.0  2024-05-29T14:59:04.789       V
# 2    2024-05-29T14:57:34.789   180.0  2024-05-29T14:59:04.789       V
# 3    2024-05-29T14:57:34.789   180.0  2024-05-29T14:59:04.789       V
# 4    2024-05-29T14:57:34.789   180.0  2024-05-29T14:59:04.789       V
# ..                       ...     ...                      ...     ...
# 171  2024-05-29T14:57:34.789   180.0  2024-05-29T14:59:04.789       V
# 172  2024-05-29T14:57:34.789   180.0  2024-05-29T14:59:04.789       V
# 173  2024-05-29T14:57:34.789   180.0  2024-05-29T14:59:04.789       V
# 174  2024-05-29T14:57:34.789   180.0  2024-05-29T14:59:04.789       V
# 175  2024-05-29T14:57:34.789   180.0  2024-05-29T14:59:04.789       V
#
#            y0 V_magnitude
# 0   -22.97869    9.762392
# 1   -22.97869   10.616849
# 2   -22.97869   11.632337
# 3   -22.97869    9.602829
# 4   -22.97869   10.451106
# ..        ...         ...
# 171 -22.97869   10.995789
# 172 -22.97869   10.597044
# 173 -22.97869   10.433938
# 174 -22.97869   10.438610
# 175 -22.97869    8.142673
#
# [176 rows x 22 columns]

# %%
print(len(df_csv))
df_csv
print(len(df))
df
# Out:
# 867
# 137574
#      Unnamed: 0   id      xcenter      ycenter  aperture_sum          msky  \
# 0             0    1    12.731777     5.566650  4.010129e+06  17284.414472
# 1             1    2  1510.409918     8.652715  4.464316e+06  17449.023116
# 2             2    3   164.490804    10.340680  4.430597e+06  17390.216213
# 3             3    4   529.834940    13.633180  4.559450e+06  17429.901042
# 4             4    5    31.221037    18.205094  4.420145e+06  17286.439298
# ..          ...  ...          ...          ...           ...           ...
# 862         862  863  1808.178808  2025.070726  4.720551e+06  18370.256457
# 863         863  864  1502.092523  2030.203431  4.640015e+06  18414.761259
# 864         864  865  1602.914476  2032.281709  4.697651e+06  18390.780092
# 865         865  866  1796.304459  2032.317564  4.692974e+06  18376.773207
# 866         866  867  1212.067675  2035.954949  4.634563e+06  18414.180376
#
#         sky_std    nsky  nrej      flux_star  ...  t_expos  \
# 0    121.046208   795.0  10.0 -388218.393161  ...    210.0
# 1    112.133780  1350.0   5.0   24080.206261  ...    210.0
# 2    118.607688  1376.0  20.0    5326.306713  ...    210.0
# 3    111.620678  1472.0  12.0  124080.890442  ...    210.0
# 4    123.331204  1493.0  31.0   21281.561202  ...    210.0
# ..          ...     ...   ...            ...  ...      ...
# 862  120.903643  1731.0  19.0   45890.519316  ...    180.0
# 863  116.784326  1556.0  17.0  -45970.743257  ...    180.0
# 864  120.248336  1503.0  11.0   17767.400020  ...    180.0
# 865  118.595890  1493.0  20.0   16654.868473  ...    180.0
# 866  119.637374  1404.0  14.0  -51275.600466  ...    180.0
#
#                     t_middle  filter zeropt_med zeropt_avg  e_zeropt  \
# 0    2024-06-28T12:21:43.244       R -25.803457 -26.052344  0.005348
# 1    2024-06-28T12:21:43.244       R -25.803457 -26.052344  0.005348
# 2    2024-06-28T12:21:43.244       R -25.803457 -26.052344  0.005348
# 3    2024-06-28T12:21:43.244       R -25.803457 -26.052344  0.005348
# 4    2024-06-28T12:21:43.244       R -25.803457 -26.052344  0.005348
# ..                       ...     ...        ...        ...       ...
# 862  2024-06-28T19:22:41.975       V -25.415691 -25.461915  0.010087
# 863  2024-06-28T19:22:41.975       V -25.415691 -25.461915  0.010087
# 864  2024-06-28T19:22:41.975       V -25.415691 -25.461915  0.010087
# 865  2024-06-28T19:22:41.975       V -25.415691 -25.461915  0.010087
# 866  2024-06-28T19:22:41.975       V -25.415691 -25.461915  0.010087
#
#     R_magnitude     RAJ2000    DEJ2000  V_magnitude
# 0           NaN  283.670328  51.694644          NaN
# 1     14.849306  283.638185  51.179101          NaN
# 2     16.487391  283.669513  51.642329          NaN
# 3     13.069195  283.663021  51.516513          NaN
# 4     14.983448  283.676925  51.688100          NaN
# ..          ...         ...        ...          ...
# 862         NaN  284.953233  51.039975    13.761384
# 863         NaN  284.966824  51.145071          NaN
# 864         NaN  284.964401  51.110368    14.791631
# 865         NaN  284.957612  51.043894    14.861838
# 866         NaN  284.980270  51.244648          NaN
#
# [137574 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'xcenter', 'ycenter', 'aperture_sum', 'msky',
#        'sky_std', 'nsky', 'nrej', 'flux_star', 'flux_err', 'mag_ann',
#        'merr_ann', 'filename', 't_start', 't_expos', 't_middle', 'filter',
#        'zeropt_med', 'zeropt_avg', 'e_zeropt', 'R_magnitude', 'RAJ2000',
#        'DEJ2000', 'V_magnitude'],
#       dtype='object')

# %%
df.drop(columns=['Unnamed: 0', 'id'], axis=0)
# df.drop(['Unnamed: 0', 'id'], axis=0)
df.reset_index(inplace=True)
df
# Out:
#         index  Unnamed: 0   id      xcenter      ycenter  aperture_sum  \
# 0           0           0    1    12.731777     5.566650  4.010129e+06
# 1           1           1    2  1510.409918     8.652715  4.464316e+06
# 2           2           2    3   164.490804    10.340680  4.430597e+06
# 3           3           3    4   529.834940    13.633180  4.559450e+06
# 4           4           4    5    31.221037    18.205094  4.420145e+06
# ...       ...         ...  ...          ...          ...           ...
# 137569    862         862  863  1808.178808  2025.070726  4.720551e+06
# 137570    863         863  864  1502.092523  2030.203431  4.640015e+06
# 137571    864         864  865  1602.914476  2032.281709  4.697651e+06
# 137572    865         865  866  1796.304459  2032.317564  4.692974e+06
# 137573    866         866  867  1212.067675  2035.954949  4.634563e+06
#
#                 msky     sky_std    nsky  nrej  ...  t_expos  \
# 0       17284.414472  121.046208   795.0  10.0  ...    210.0
# 1       17449.023116  112.133780  1350.0   5.0  ...    210.0
# 2       17390.216213  118.607688  1376.0  20.0  ...    210.0
# 3       17429.901042  111.620678  1472.0  12.0  ...    210.0
# 4       17286.439298  123.331204  1493.0  31.0  ...    210.0
# ...              ...         ...     ...   ...  ...      ...
# 137569  18370.256457  120.903643  1731.0  19.0  ...    180.0
# 137570  18414.761259  116.784326  1556.0  17.0  ...    180.0
# 137571  18390.780092  120.248336  1503.0  11.0  ...    180.0
# 137572  18376.773207  118.595890  1493.0  20.0  ...    180.0
# 137573  18414.180376  119.637374  1404.0  14.0  ...    180.0
#
#                        t_middle  filter  zeropt_med zeropt_avg  e_zeropt  \
# 0       2024-06-28T12:21:43.244       R  -25.803457 -26.052344  0.005348
# 1       2024-06-28T12:21:43.244       R  -25.803457 -26.052344  0.005348
# 2       2024-06-28T12:21:43.244       R  -25.803457 -26.052344  0.005348
# 3       2024-06-28T12:21:43.244       R  -25.803457 -26.052344  0.005348
# 4       2024-06-28T12:21:43.244       R  -25.803457 -26.052344  0.005348
# ...                         ...     ...         ...        ...       ...
# 137569  2024-06-28T19:22:41.975       V  -25.415691 -25.461915  0.010087
# 137570  2024-06-28T19:22:41.975       V  -25.415691 -25.461915  0.010087
# 137571  2024-06-28T19:22:41.975       V  -25.415691 -25.461915  0.010087
# 137572  2024-06-28T19:22:41.975       V  -25.415691 -25.461915  0.010087
# 137573  2024-06-28T19:22:41.975       V  -25.415691 -25.461915  0.010087
#
#         R_magnitude     RAJ2000    DEJ2000  V_magnitude
# 0               NaN  283.670328  51.694644          NaN
# 1         14.849306  283.638185  51.179101          NaN
# 2         16.487391  283.669513  51.642329          NaN
# 3         13.069195  283.663021  51.516513          NaN
# 4         14.983448  283.676925  51.688100          NaN
# ...             ...         ...        ...          ...
# 137569          NaN  284.953233  51.039975    13.761384
# 137570          NaN  284.966824  51.145071          NaN
# 137571          NaN  284.964401  51.110368    14.791631
# 137572          NaN  284.957612  51.043894    14.861838
# 137573          NaN  284.980270  51.244648          NaN
#
# [137574 rows x 26 columns]

# %%
EXO_coord = {"Qatar-1b":["20:13:31.6176 65:09:43.490"], 
             "Qatar-10b":["20:13:31.6176 65:09:43.490"], 
             "HAT-P-37b":["18:57:11.0562 51:16:08.849"],
             }
EXO_coord
# Out:
# {'Qatar-1b': ['20:13:31.6176 65:09:43.490'],
#  'Qatar-10b': ['20:13:31.6176 65:09:43.490'],
#  'HAT-P-37b': ['18:57:11.0562 51:16:08.849']}

# %%
EXO_name = "Qatar-1b"
EXO_name = "HAT-P-37b"

EXO_coord[EXO_name]
# Out:
# ['18:57:11.0562 51:16:08.849']

# %%
targ_sky = SkyCoord(EXO_coord[EXO_name], 
                    frame="fk5", unit=(u.hourangle, u.deg)
                    )

targ_sky
targ_sky.ra.value[0]
type(targ_sky.ra.value[0])

coord_delta = 0.00005

# %%
print(df.columns)

df_star = df.loc[(df["RAJ2000"] > targ_sky.ra.value[0]*(1-coord_delta)) \
                 & (df["RAJ2000"] < targ_sky.ra.value[0]*(1+coord_delta)) \
                 & (df["DEJ2000"] > targ_sky.dec.value[0]*(1-coord_delta))\
                 & (df["DEJ2000"] < targ_sky.dec.value[0]*(1+coord_delta))]

df_star
data = df_star[['t_middle', 'filter', 'R_magnitude', 'V_magnitude', 'merr_ann']]
data
# Out:
# Index(['index', 'Unnamed: 0', 'id', 'xcenter', 'ycenter', 'aperture_sum',
#        'msky', 'sky_std', 'nsky', 'nrej', 'flux_star', 'flux_err', 'mag_ann',
#        'merr_ann', 'filename', 't_start', 't_expos', 't_middle', 'filter',
#        'zeropt_med', 'zeropt_avg', 'e_zeropt', 'R_magnitude', 'RAJ2000',
#        'DEJ2000', 'V_magnitude'],
#       dtype='object')
#                        t_middle filter  R_magnitude  V_magnitude  merr_ann
# 634     2024-06-28T12:21:43.244      R    13.106386          NaN  0.022989
# 1729    2024-06-28T12:28:47.427      R    13.259364          NaN  0.025528
# 2825    2024-06-28T12:35:52.573      R    12.760192          NaN  0.015376
# 3943    2024-06-28T12:42:56.756      R    12.877522          NaN  0.016558
# 5078    2024-06-28T12:50:00.943      R    13.563046          NaN  0.030467
# ...                         ...    ...          ...          ...       ...
# 133028  2024-06-28T18:33:10.636      V          NaN    13.413437  0.024070
# 134094  2024-06-28T18:47:19.544      V          NaN    14.037517  0.044823
# 135117  2024-06-28T19:01:28.441      V          NaN    14.512509  0.077497
# 136073  2024-06-28T19:15:37.477      V          NaN    13.064000  0.024633
# 137012  2024-06-28T19:22:41.975      V          NaN          NaN -0.071294
#
# [106 rows x 5 columns]

# %%
df_star['t_middle_dt'] = pd.to_datetime(df['t_middle'])
# Out:
# /tmp/ipykernel_78780/3312728216.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_star['t_middle_dt'] = pd.to_datetime(df['t_middle'])

# %%
df_star['t_middle_dt']
# Out:
# 634      2024-06-28 12:21:43.244
# 1729     2024-06-28 12:28:47.427
# 2825     2024-06-28 12:35:52.573
# 3943     2024-06-28 12:42:56.756
# 5078     2024-06-28 12:50:00.943
#                    ...
# 133028   2024-06-28 18:33:10.636
# 134094   2024-06-28 18:47:19.544
# 135117   2024-06-28 19:01:28.441
# 136073   2024-06-28 19:15:37.477
# 137012   2024-06-28 19:22:41.975
# Name: t_middle_dt, Length: 106, dtype: datetime64[ns]

# %%
df_star["t_middle"]
# Out:
# 234      2024-05-29T12:08:14.152
# 620      2024-05-29T12:16:55.657
# 940      2024-05-29T12:19:45.345
# 1223     2024-05-29T12:28:46.672
# 1455     2024-05-29T12:31:52.771
# 1693     2024-05-29T12:40:31.267
# 2022     2024-05-29T12:43:23.978
# 2434     2024-05-29T12:52:18.749
# 2857     2024-05-29T12:55:06.617
# 3390     2024-05-29T13:03:48.428
# 3990     2024-05-29T13:06:42.252
# 4581     2024-05-29T13:15:18.299
# 5190     2024-05-29T13:18:15.602
# 6365     2024-05-29T13:39:47.936
# 7064     2024-05-29T13:43:03.132
# 7645     2024-05-29T13:52:41.012
# 8129     2024-05-29T13:55:34.900
# 9212     2024-05-29T14:07:12.078
# 13534    2024-05-29T12:11:38.282
# 13873    2024-05-29T12:14:37.336
# 14172    2024-05-29T12:23:09.219
# 14398    2024-05-29T12:26:24.873
# 14550    2024-05-29T12:34:59.462
# 14699    2024-05-29T12:38:07.090
# 14913    2024-05-29T12:46:50.080
# 15206    2024-05-29T12:50:00.455
# 15470    2024-05-29T12:58:31.338
# 15809    2024-05-29T13:01:17.900
# 16245    2024-05-29T13:10:01.737
# 16733    2024-05-29T13:12:54.625
# 17238    2024-05-29T13:21:41.908
# 17732    2024-05-29T13:24:36.701
# 18843    2024-05-29T13:46:27.866
# 19365    2024-05-29T13:49:43.626
# 19806    2024-05-29T13:59:12.152
# Name: t_middle, dtype: object

# %%
# ttime = Time(df_star["t_middle"][0])
# type(ttime)
# # len(ttime)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/envs/astro_Python_env/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 ttime = Time(df_star["t_middle"][0])
#       2 type(ttime)
#
# File ~/anaconda3/envs/astro_Python_env/lib/python3.11/site-packages/pandas/core/series.py:1112, in Series.__getitem__(self, key)
#    1109     return self._values[key]
#    1111 elif key_is_scalar:
# -> 1112     return self._get_value(key)
#    1114 # Convert generator to list before going through hashable part
#    1115 # (We will iterate through the generator there to check for slices)
#    1116 if is_iterator(key):
#
# File ~/anaconda3/envs/astro_Python_env/lib/python3.11/site-packages/pandas/core/series.py:1228, in Series._get_value(self, label, takeable)
#    1225     return self._values[label]
#    1227 # Similar to Index.get_value, but we do not fall back to positional
# -> 1228 loc = self.index.get_loc(label)
#    1230 if is_integer(loc):
#    1231     return self._values[loc]
#
# File ~/anaconda3/envs/astro_Python_env/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 0

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5), sharex=False, sharey=False, gridspec_kw=None)

axs[0].errorbar(df_star["t_middle_dt"], 
            df_star['R_magnitude'], yerr=abs(df_star["merr_ann"]),
            marker='x',
            ecolor="red",
            mfc='red',
            mec='red',
            ls='none',
            #ms=10,
            capsize=3,
            label="Rmag")
axs[0].errorbar(df_star["t_middle_dt"], 
            df_star['V_magnitude']+3, yerr=abs(df_star["merr_ann"]),
            marker='x',
            # ecolor="yellow",
            # mfc='yellow',
            # mec='yellow',
            ecolor="green",
            mfc='green',
            mec='green',
            ls='none',
            #ms=10,
            capsize=3,
            label="Vmag+3")

axs[0].invert_yaxis()  
axs[0].set(
    xlabel='Time',
    ylabel="mag"
)
axs[0].legend()

axs[1].invert_yaxis()
axs[1].set(
    xlabel=f"Time",
    ylabel="mag"
)

plt.suptitle(f"Result of ligjt curve", fontsize=12,)

plt.tight_layout()
# plt.savefig(f"{DIFFPRESULTDIR}/{fpath.stem}_standardization1.png")

# plt.show()
# plt.close()

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5), sharex=False, sharey=False, gridspec_kw=None)

for idx, row in df_star.iterrows():

    axs[0].errorbar(row["t_middle_dt"], 
                row['R_magnitude'], yerr=abs(row["merr_ann"]),
                marker='x',
                ecolor="red",
                mfc='red',
                mec='red',
                ls='none',
                #ms=10,
                capsize=3,
                label="Rmag")
    axs[0].errorbar(row["t_middle_dt"], 
                row['V_magnitude']+2, yerr=abs(row["merr_ann"]),
                marker='x',
                ecolor="yellow",
                mfc='yellow',
                mec='yellow',
                ls='none',
                #ms=10,
                capsize=3,
                label="Vmag")

axs[0].invert_yaxis()
axs[1].invert_yaxis()
    
axs[0].set(
    xlabel='Time',
    ylabel="mag"
)
axs[1].set(
    xlabel=f"Time",
    ylabel="mag"
)

# axs[0].legend()
plt.suptitle(f"Result of ligjt curve", fontsize=12,)

plt.tight_layout()
# plt.savefig(f"{DIFFPRESULTDIR}/{fpath.stem}_standardization1.png")

# plt.show()
# plt.close()
