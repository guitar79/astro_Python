# %% [markdown]
# # 06_02_tracing_calibration

# %% [markdown]
# ## 필요한 모듈
#
# 이 프로젝트를 위해서는 아래의 모듈이 필요하다.
#
# > numpy, pandas, matplotlib, astropy, version_information

# %% [markdown]
# ### 모듈 설치
#
# 1. 콘솔 창에서 모듈을 설치할 때는 아래와 같은 형식으로 입력하면 된다.
#
# >pip install module_name==version
#
# >conda install module_name==version
#
# 2. 주피터 노트북(코랩 포함)에 설치 할 때는 아래의 셀을 실행해서 실행되지 않은 모듈을 설치할 수 있다. (pip 기준) 만약 아나콘다 환경을 사용한다면 7행을 콘다 설치 명령어에 맞게 수정하면 된다.

# %%
# Install a pip package in the current Jupyter kernel
import importlib, sys, subprocess
print(f"sys.executable: {sys.executable}")

packages = "numpy, pandas, matplotlib, scipy, astropy, photutils, ccdproc, version_information" # required modules
pkgs = packages.split(", ")
for pkg in pkgs :
    if not importlib.util.find_spec(pkg):
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', pkg, '-q'])
        print(f"**** {pkg} module is now installed.")
    else: 
        print(f"******** {pkg} module is already installed.")
# %load_ext version_information
import time
now = time.strftime("%Y-%m-%d %H:%M:%S (%Z = GMT%z)")
print(f"This notebook was generated at {now} ")

vv = %version_information {packages}
for i, pkg in enumerate(vv.packages):
    print(f"{i} {pkg[0]:10s} {pkg[1]:s}")
# Out:
# sys.executable: /home/guitar79/anaconda3/envs/astro_Python_env/bin/python
# ******** numpy module is already installed.
# ******** pandas module is already installed.
# ******** matplotlib module is already installed.
# ******** scipy module is already installed.
# ******** astropy module is already installed.
# ******** photutils module is already installed.
# ******** ccdproc module is already installed.
# ******** version_information module is already installed.
# The version_information extension is already loaded. To reload it, use:
#   %reload_ext version_information
# This notebook was generated at 2024-09-04 15:33:24 (KST = GMT+0900)
# 0 Python     3.12.4 64bit [GCC 11.2.0]
# 1 IPython    8.27.0
# 2 OS         Linux 5.15.0 119 generic x86_64 with glibc2.31
# 3 numpy      1.26.4
# 4 pandas     2.2.2
# 5 matplotlib 3.9.2
# 6 scipy      1.14.1
# 7 astropy    6.1.0
# 8 photutils  1.12.0
# 9 ccdproc    2.4.2
# 10 version_information 1.0.4

# %% [markdown]
# ### 모듈 버전 확인
#
# 아래 셀을 실행하면 이 노트북을 실행한 파이썬 및 관련 모듈의 버전을 확인할 수 있다.

# %% [markdown]
# ### import modules

# %%
from glob import glob
from pathlib import Path
import os
import numpy as np
import astropy.units as u
#from astropy.stats import sigma_clip
#from ccdproc import combine, ccd_process, CCDData
from astropy.io import fits
import matplotlib.pyplot as plt

import ysfitsutilpy as yfu
#import ysphotutilpy as ypu
#import ysvisutilpy as yvu

import _astro_utilities
import _Python_utilities

# %% [markdown]
# "CAL-BDF" 폴더 찾기

# %%
#%%
BASEDIR = Path("/mnt/Rdata/OBS_data") 
PROJECDIR = BASEDIR/ "2024-Spectra"
TODODIR = PROJECDIR / "TEC140_ASI183MMPro_2024-05_1bin"
# TODODIR = PROJECDIR / "_-_-_2024-06_-_GSON300_STF-8300M_-_1bin"


DOINGDIRs = sorted(_Python_utilities.getFullnameListOfsubDirs(TODODIR))
print ("DOINGDIRs: ", format(DOINGDIRs))
print ("len(DOINGDIRs): ", format(len(DOINGDIRs)))

MASTERDIR = [x for x in DOINGDIRs if "CAL-BDF" in str(x)]
MASTERDIR = Path(MASTERDIR[0]) / _astro_utilities.master_dir
print ("MASTERDIR: ", format(MASTERDIR))

BDFDIR = [x for x in DOINGDIRs if "SPTR-CAL_" in str(x)]
print ("BDFDIR: ", format(BDFDIR))

DOINGDIRs = sorted([x for x in DOINGDIRs if "_LIGHT_" in str(x)])
DOINGDIRs = sorted([x for x in DOINGDIRs if not "SPTR-CAL_" in str(x)])
print ("DOINGDIRs: ", format(DOINGDIRs))
print ("len(DOINGDIRs): ", format(len(DOINGDIRs)))

# filter_str = '2024-08-30'
# DOINGDIRs = [x for x in DOINGDIRs if filter_str in x]
# remove = 'BIAS'
# DOINGDIRs = [x for x in DOINGDIRs if remove not in x]
# remove = 'DARK'
# DOINGDIRs = [x for x in DOINGDIRs if remove not in x]
# remove = 'FLAT'
# DOINGDIRs = [x for x in DOINGDIRs if remove not in x]
print ("DOINGDIRs: ", DOINGDIRs)
print ("len(DOINGDIRs): ", len(DOINGDIRs))
#######################################################
# Out:
# DOINGDIRs:  ['/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/-_CAL-BDF_-_2024-05-14_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-CAL_LIGHT_-_2024-05-14_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP24608-CAPELA_LIGHT_-_2024-04-26_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP27989-BETELGEUSE_LIGHT_-_2024-05-01_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP31681-ALHENA_LIGHT_-_2024-05-01_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP32246-MEBSUTA_LIGHT_-_2024-05-01_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP32349-SIRIUS_LIGHT_-_2024-04-26_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP32826-POLLUX_LIGHT_-_2024-04-26_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP36850-CASTOR_LIGHT_-_2024-04-26_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP37279-PROCYON_LIGHT_-_2024-04-26_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP37279-PROCYON_LIGHT_-_2024-05-14_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP37740_LIGHT_-_2024-05-02_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP45860_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP47908-ALGENUBI_LIGHT_-_2024-05-01_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP48455-RASALAS_LIGHT_-_2024-05-02_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP49669-REGULUS_LIGHT_-_2024-04-26_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP49669-REGULUS_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP50335-ADHAFERA_LIGHT_-_2024-05-02_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP50583-ALGIEBA_LIGHT_-_2024-05-01_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP54061-DUBHE_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP54539-ALKAPHRAH_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP54879-CHARTAN_LIGHT_-_2024-05-02_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP57632-DENEBOLA_LIGHT_-_2024-05-01_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP58001-PHECDA_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP59774-MEGREZ_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP61941-PORRIMA_LIGHT_-_2024-05-02_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP62956-ALIOTH_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP65378-MIZAR_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP65474-SPICA_LIGHT_-_2024-05-02_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC1 ...
# len(DOINGDIRs):  40
# MASTERDIR:  /mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/-_CAL-BDF_-_2024-05-14_-_TEC140_ASI183MMPro_-_1bin/master_files_ys
# BDFDIR:  ['/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-CAL_LIGHT_-_2024-05-14_-_TEC140_ASI183MMPro_-_1bin/']
# DOINGDIRs:  ['/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP24608-CAPELA_LIGHT_-_2024-04-26_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP27989-BETELGEUSE_LIGHT_-_2024-05-01_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP31681-ALHENA_LIGHT_-_2024-05-01_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP32246-MEBSUTA_LIGHT_-_2024-05-01_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP32349-SIRIUS_LIGHT_-_2024-04-26_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP32826-POLLUX_LIGHT_-_2024-04-26_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP36850-CASTOR_LIGHT_-_2024-04-26_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP37279-PROCYON_LIGHT_-_2024-04-26_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP37279-PROCYON_LIGHT_-_2024-05-14_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP37740_LIGHT_-_2024-05-02_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP45860_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP47908-ALGENUBI_LIGHT_-_2024-05-01_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP48455-RASALAS_LIGHT_-_2024-05-02_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP49669-REGULUS_LIGHT_-_2024-04-26_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP49669-REGULUS_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP50335-ADHAFERA_LIGHT_-_2024-05-02_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP50583-ALGIEBA_LIGHT_-_2024-05-01_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP54061-DUBHE_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP54539-ALKAPHRAH_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP54879-CHARTAN_LIGHT_-_2024-05-02_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP57632-DENEBOLA_LIGHT_-_2024-05-01_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP58001-PHECDA_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP59774-MEGREZ_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP61941-PORRIMA_LIGHT_-_2024-05-02_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP62956-ALIOTH_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP65378-MIZAR_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP65474-SPICA_LIGHT_-_2024-05-02_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP65477-ALCOR_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP69673-ARCTURUS_LIGHT_-_2024-04-26_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rd ...
# len(DOINGDIRs):  38
# DOINGDIRs:  ['/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP24608-CAPELA_LIGHT_-_2024-04-26_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP27989-BETELGEUSE_LIGHT_-_2024-05-01_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP31681-ALHENA_LIGHT_-_2024-05-01_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP32246-MEBSUTA_LIGHT_-_2024-05-01_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP32349-SIRIUS_LIGHT_-_2024-04-26_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP32826-POLLUX_LIGHT_-_2024-04-26_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP36850-CASTOR_LIGHT_-_2024-04-26_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP37279-PROCYON_LIGHT_-_2024-04-26_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP37279-PROCYON_LIGHT_-_2024-05-14_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP37740_LIGHT_-_2024-05-02_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP45860_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP47908-ALGENUBI_LIGHT_-_2024-05-01_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP48455-RASALAS_LIGHT_-_2024-05-02_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP49669-REGULUS_LIGHT_-_2024-04-26_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP49669-REGULUS_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP50335-ADHAFERA_LIGHT_-_2024-05-02_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP50583-ALGIEBA_LIGHT_-_2024-05-01_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP54061-DUBHE_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP54539-ALKAPHRAH_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP54879-CHARTAN_LIGHT_-_2024-05-02_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP57632-DENEBOLA_LIGHT_-_2024-05-01_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP58001-PHECDA_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP59774-MEGREZ_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP61941-PORRIMA_LIGHT_-_2024-05-02_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP62956-ALIOTH_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP65378-MIZAR_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP65474-SPICA_LIGHT_-_2024-05-02_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP65477-ALCOR_LIGHT_-_2024-05-13_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-HIP69673-ARCTURUS_LIGHT_-_2024-04-26_-_TEC140_ASI183MMPro_-_1bin/', '/mnt/Rd ...
# len(DOINGDIRs):  38

# %% [markdown]
# ## Cal file Summary

# %%
BDFDIR = Path(BDFDIR[0])
print("BDFDIR", BDFDIR)

summary = yfu.make_summary(BDFDIR / "*.fit*")
if summary is not None : 
    #print(summary)
    print("len(summary):", len(summary))
    print("summary:", summary)
    #print(summary["file"][0])
# Out:
# BDFDIR /mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-CAL_LIGHT_-_2024-05-14_-_TEC140_ASI183MMPro_-_1bin
# All 49 keywords (guessed from /mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183MMPro_2024-05_1bin/SPTR-CAL_LIGHT_-_2024-05-14_-_TEC140_ASI183MMPro_-_1bin/SPTR-CAL_LIGHT__2024-05-14-06-15-05_2sec_TEC140_ASI183MMPro_-9c_1bin.fit) will be loaded.
# len(summary): 69
# summary:                                                  file  filesize  SIMPLE  \
# 0   /mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183...  40368960    True
# 1   /mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183...  40368960    True
# 2   /mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183...  40368960    True
# 3   /mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183...  40368960    True
# 4   /mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183...  40368960    True
# ..                                                ...       ...     ...
# 64  /mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183...  40368960    True
# 65  /mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183...  40368960    True
# 66  /mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183...  40368960    True
# 67  /mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183...  40368960    True
# 68  /mnt/Rdata/OBS_data/2024-Spectra/TEC140_ASI183...  40368960    True
#
#     BITPIX  NAXIS  NAXIS1  NAXIS2  EXTEND  BZERO IMAGETYP  ...   OBJCTDEC  \
# 0       16      2    5496    3672    True  32768    LIGHT  ...  +07 28 34
# 1       16      2    5496    3672    True  32768    LIGHT  ...  +07 28 34
# 2       16      2    5496    3672    True  32768    LIGHT  ...  +07 28 34
# 3       16      2    5496    3672    True  32768    LIGHT  ...  +07 28 34
# 4       16      2    5496    3672    True  32768    LIGHT  ...  +07 28 34
# ..     ...    ...     ...     ...     ...    ...      ...  ...        ...
# 64      16      2    5496    3672    True  32768    LIGHT  ...  +07 28 34
# 65      16      2    5496    3672    True  32768    LIGHT  ...  +07 28 34
# 66      16      2    5496    3672    True  32768    LIGHT  ...  +07 28 34
# 67      16      2    5496    3672    True  32768    LIGHT  ...  +07 28 34
# 68      16      2    5496    3672    True  32768    LIGHT  ...  +07 28 34
#
#     ROWORDER EQUINOX                   SWCREATE      CCDNAME  FILTER   OPTIC  \
# 0   TOP-DOWN  2000.0  N.I.N.A. 3.1.0.2001 (x64)  ASI183MMPro          TEC140
# 1   TOP-DOWN  2000.0  N.I.N.A. 3.1.0.2001 (x64)  ASI183MMPro          TEC140
# 2   TOP-DOWN  2000.0  N.I.N.A. 3.1.0.2001 (x64)  ASI183MMPro          TEC140
# 3   TOP-DOWN  2000.0  N.I.N.A. 3.1.0.2001 (x64)  ASI183MMPro          TEC140
# 4   TOP-DOWN  2000.0  N.I.N.A. 3.1.0.2001 (x64)  ASI183MMPro          TEC140
# ..       ...     ...                        ...          ...     ...     ...
# 64  TOP-DOWN  2000.0  N.I.N.A. 3.1.0.2001 (x64)  ASI183MMPro          TEC140
# 65  TOP-DOWN  2000.0  N.I.N.A. 3.1.0.2001 (x64)  ASI183MMPro          TEC140
# 66  TOP-DOWN  2000.0  N.I.N.A. 3.1.0.2001 (x64)  ASI183MMPro          TEC140
# 67  TOP-DOWN  2000.0  N.I.N.A. 3.1.0.2001 (x64)  ASI183MMPro          TEC140
# 68  TOP-DOWN  2000.0  N.I.N.A. 3.1.0.2001 (x64)  ASI183MMPro          TEC140
#
#     APATURE  PIXSCALE  FLIPSTAT
# 0       140  0.505139
# 1       140  0.505139
# 2       140  0.505139
# 3       140  0.505139
# 4       140  0.505139
# ..      ...       ...       ...
# 64      140  0.505139
# 65      140  0.505139
# 66      140  0.505139
# 67      140  0.505139
# 68      140  0.505139
#
# [69 rows x 51 columns]

# %% [markdown]
# ### 분광 자료 display

# %%
fpath = Path(summary["file"][0])
hdul = fits.open(fpath)

fig, axs = plt.subplots(1, 2, figsize=(13, 6), sharex=False, sharey=False, gridspec_kw=None)

im1 = _astro_utilities.zimshow(axs[0], 
                    hdul[0].data,
                    origin="lower",
                    cmap = "viridis"
                    )
im2 = axs[1].hist(hdul[0].data,
                )

axs[0].set_title('The Calibration image (zimshow)')
axs[1].set_title('The histrogram of pixel value ')

plt.annotate(f"Min value: {hdul[0].data.min()}, Mean value: {hdul[0].data.mean():.02f}, Max value: {hdul[0].data.max()}", xy=(0, -50), xycoords='axes pixels')

plt.colorbar(im1, fraction=0.0455, pad=0.04)
plt.tight_layout(pad=5.0)

# %%
fpath = Path(summary["file"][0])
hdul = fits.open(fpath)

fig, axs = plt.subplots(1, 1, figsize=(12, 4), sharex=False, sharey=False, gridspec_kw=None)

im1 = _astro_utilities.zimshow(axs, 
                                hdul[0].data[1700:1950, :],
                                origin="lower",
                                cmap = "viridis",
                                )

axs.set_title('The spectra image (zimshow)')

plt.colorbar(im1, fraction=0.15, pad=0.3, location='bottom')
plt.tight_layout(pad=5.0)

# %%
fpath = Path(summary["file"][3])
hdul = fits.open(fpath)

fig, axs = plt.subplots(1, 1, figsize=(12, 4), sharex=False, sharey=False, gridspec_kw=None)

im1 = _astro_utilities.zimshow(axs, 
                                np.flip(hdul[0].data[1700:1900, :], axis=1), # flip horizental
                                origin="lower",
                                cmap = "viridis",
                                )

axs.set_title('The spectra image (zimshow)')

plt.colorbar(im1, fraction=0.15, pad=0.3, location='bottom')
plt.tight_layout(pad=5.0)

# %%
import matplotlib.pyplot as plt
from astropy.io import fits

plt.figure(figsize=(18, 4))  
data = np.flip(hdul[0].data[1800:1950, :], axis=1)
header = hdul[0].header

# 필요한 데이터 추출
wavelength = data[0,:]
flux = data[1]

# 플롯 생성
plt.plot(flux)
plt.xlabel('Wavelength (Angstrom)')
plt.ylabel('Flux')
plt.title('Spectrum of a Standard Star')
plt.show()

# %% [markdown]
# # Step 1: Examine the spectrum
#
# https://github.com/astropy/astropy-tutorials/blob/main/tutorials/SpectroscopicDataReductionBasics/1-SpectroscopicTraceTutorial.ipynb

# %%
yvals = np.argmax(hdul[0].data, axis=0)
xvals = np.arange(hdul[0].data.shape[1])

plt.plot(xvals, yvals, 'x')
plt.ylabel("Argmax trace data")
plt.xlabel("X position");

# %%
ylow, yhigh = 1700, 1900 
bad_pixels = (yvals < ylow) | (yvals > yhigh)

plt.plot(xvals, yvals, 'x')
plt.plot(xvals[bad_pixels], yvals[bad_pixels], 'rx')
plt.ylabel("Argmax trace data")
plt.xlabel("X position");

# %%
plt.plot(xvals[~bad_pixels], yvals[~bad_pixels], 'x')
plt.ylabel("Argmax trace data")
plt.xlabel("X position")
# Out:
# Text(0.5, 0, 'X position')

# %%
ylow, yhigh = 1775, 1900 
bad_pixels = (yvals < ylow) | (yvals > yhigh)

plt.plot(xvals[~bad_pixels], yvals[~bad_pixels], 'x')
plt.ylabel("Argmax trace data")
plt.xlabel("X position")
# Out:
# Text(0.5, 0, 'X position')

# %%
plt.imshow(hdul[0].data[ylow:yhigh, :],
           origin="lower")
plt.gca().set_aspect(10)

# %% [markdown]
# ## Step 2b: Use moment analysis to extract a spine to trace

# %%
# we use a cutout around the traced line, so the Y-values are from that cutout
# the `repeat` command here is used to extend our Y-axis position values, which are 425, 426, ... 475
# along the X-direction.  The indexing with [:, None] adds a "dummy" axis along the second (x) dimension,
# then `repeat` copies our Y-axis values.  The resulting array has the same shape as our weight array,
# which is hdul[0].data[425:475, :] minus the median
yaxis = np.repeat(np.arange(ylow, yhigh)[:,None],
                  hdul[0].data.shape[1], axis=1)
background = np.median(hdul[0].data)
# moment 1 is the data-weighted average of the Y-axis coordinates
weighted_yaxis_values = np.average(yaxis, axis=0,
                                   weights=hdul[0].data[ylow:yhigh,:] - background)
print("weighted_yaxis_values ", weighted_yaxis_values)
print("weighted_yaxis_values.shape :", weighted_yaxis_values.shape)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[91], line 10
#       8 background = np.median(hdul[0].data)
#       9 # moment 1 is the data-weighted average of the Y-axis coordinates
# ---> 10 weighted_yaxis_values = np.average(yaxis, axis=0,
#      11                                    weights=hdul[0].data[ylow:yhigh,:] - background)
#      12 print("weighted_yaxis_values ", weighted_yaxis_values)
#      13 print("weighted_yaxis_values.shape :", weighted_yaxis_values.shape)
#
# File ~/anaconda3/envs/astro_Python_env/lib/python3.12/site-packages/numpy/lib/function_base.py:550, in average(a, axis, weights, returned, keepdims)
#     548     scl = wgt.sum(axis=axis, dtype=result_dtype, **keepdims_kw)
#     549     if np.any(scl == 0.0):
# --> 550         raise ZeroDivisionError(
#     551             "Weights sum to zero, can't be normalized")
#     553     avg = avg_as_array = np.multiply(a, wgt,
#     554                       dtype=result_dtype).sum(axis, **keepdims_kw) / scl
#     556 if returned:
#
# ZeroDivisionError: Weights sum to zero, can't be normalized

# %%
plt.plot(xvals, weighted_yaxis_values, 'x')
plt.xlabel("X Coordinate")
plt.ylabel("Moment-1 estimated Y-value trace");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 plt.plot(xvals, weighted_yaxis_values, 'x')
#       2 plt.xlabel("X Coordinate")
#       3 plt.ylabel("Moment-1 estimated Y-value trace");
#
# NameError: name 'weighted_yaxis_values' is not defined

# %%
# we need to use the 'extent' keyword to have the axes correctly labeled
plt.imshow(hdul[0].data[ylow:yhigh,:],
          extent=[0,hdul[0].data.shape[1],ylow,yhigh],
          origin="lower")
plt.gca().set_aspect(10) # we stretch the image out by 10x in the y-direction
plt.plot(xvals, weighted_yaxis_values, 'wx', alpha=0.5)
plt.axis((0,hdul[0].data.shape[1],ylow,yhigh));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 6
#       2 plt.imshow(hdul[0].data[ylow:yhigh,:],
#       3           extent=[0,hdul[0].data.shape[1],ylow,yhigh],
#       4           origin="lower")
#       5 plt.gca().set_aspect(10) # we stretch the image out by 10x in the y-direction
# ----> 6 plt.plot(xvals, weighted_yaxis_values, 'wx', alpha=0.5)
#       7 plt.axis((0,hdul[0].data.shape[1],ylow,yhigh));
#
# NameError: name 'weighted_yaxis_values' is not defined

# %%
plt.plot(xvals, weighted_yaxis_values, 'x', label="Weighted", alpha=0.5)
plt.plot(xvals[~bad_pixels], yvals[~bad_pixels], '+', label="Argmax", alpha=0.5)
plt.legend(loc='best');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 plt.plot(xvals, weighted_yaxis_values, 'x', label="Weighted", alpha=0.5)
#       2 plt.plot(xvals[~bad_pixels], yvals[~bad_pixels], '+', label="Argmax", alpha=0.5)
#       3 plt.legend(loc='best');
#
# NameError: name 'weighted_yaxis_values' is not defined

# %%
wei_ylow, wei_yhigh = 1775, 1875
bad_moments = (weighted_yaxis_values > wei_yhigh) | (weighted_yaxis_values < wei_ylow)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 wei_ylow, wei_yhigh = 1775, 1875
# ----> 2 bad_moments = (weighted_yaxis_values > wei_yhigh) | (weighted_yaxis_values < wei_ylow)
#
# NameError: name 'weighted_yaxis_values' is not defined

# %%
plt.plot(xvals[~bad_moments], weighted_yaxis_values[~bad_moments], 'x', label="Weighted", alpha=0.5)
plt.plot(xvals[~bad_pixels], yvals[~bad_pixels], '+', label="Argmax", alpha=0.5)
plt.legend(loc='best');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 plt.plot(xvals[~bad_moments], weighted_yaxis_values[~bad_moments], 'x', label="Weighted", alpha=0.5)
#       2 plt.plot(xvals[~bad_pixels], yvals[~bad_pixels], '+', label="Argmax", alpha=0.5)
#       3 plt.legend(loc='best');
#
# NameError: name 'bad_moments' is not defined

# %% [markdown]
#
# ## Step 3. Fit the trace profile

# %%
from astropy.modeling.polynomial import Polynomial1D
from astropy.modeling.fitting import LinearLSQFitter, LevMarLSQFitter

# %%
# We fit a 2nd-order polynomial
polymodel = Polynomial1D(degree=2)
linfitter = LinearLSQFitter()
# linfitter = LevMarLSQFitter()
fitted_polymodel = linfitter(polymodel, xvals[~bad_moments], weighted_yaxis_values[~bad_moments])
fitted_polymodel
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 5
#       3 linfitter = LinearLSQFitter()
#       4 # linfitter = LevMarLSQFitter()
# ----> 5 fitted_polymodel = linfitter(polymodel, xvals[~bad_moments], weighted_yaxis_values[~bad_moments])
#       6 fitted_polymodel
#
# NameError: name 'bad_moments' is not defined

# %%
plt.plot(xvals[~bad_moments], weighted_yaxis_values[~bad_moments], 'x', alpha=0.5)
plt.plot(xvals, fitted_polymodel(xvals), color='r');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 plt.plot(xvals[~bad_moments], weighted_yaxis_values[~bad_moments], 'x', alpha=0.5)
#       2 plt.plot(xvals, fitted_polymodel(xvals), color='r');
#
# NameError: name 'bad_moments' is not defined

# %%
plt.plot(xvals[~bad_moments],
        weighted_yaxis_values[~bad_moments] - fitted_polymodel(xvals[~bad_moments]), 'x')
plt.ylabel("Residual (data-model)");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 plt.plot(xvals[~bad_moments],
#       2         weighted_yaxis_values[~bad_moments] - fitted_polymodel(xvals[~bad_moments]), 'x')
#       3 plt.ylabel("Residual (data-model)");
#
# NameError: name 'bad_moments' is not defined

# %%
polymodel = Polynomial1D(degree=3)
fitted_polymodel = linfitter(polymodel, xvals[~bad_moments], weighted_yaxis_values[~bad_moments])
print("fitted_polymodel :", fitted_polymodel)

plt.plot(xvals[~bad_moments], weighted_yaxis_values[~bad_moments], 'x', alpha=0.5)
plt.plot(xvals, fitted_polymodel(xvals), color='r');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 2
#       1 polymodel = Polynomial1D(degree=3)
# ----> 2 fitted_polymodel = linfitter(polymodel, xvals[~bad_moments], weighted_yaxis_values[~bad_moments])
#       3 print("fitted_polymodel :", fitted_polymodel)
#       5 plt.plot(xvals[~bad_moments], weighted_yaxis_values[~bad_moments], 'x', alpha=0.5)
#
# NameError: name 'bad_moments' is not defined

# %%
plt.plot(xvals[~bad_moments],
        weighted_yaxis_values[~bad_moments] - fitted_polymodel(xvals[~bad_moments]), 'x')
plt.ylabel("Residual (data-model)");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 plt.plot(xvals[~bad_moments],
#       2         weighted_yaxis_values[~bad_moments] - fitted_polymodel(xvals[~bad_moments]), 'x')
#       3 plt.ylabel("Residual (data-model)");
#
# NameError: name 'bad_moments' is not defined

# %%
plt.imshow(hdul[0].data[ylow:yhigh,:],
          extent=[0,hdul[0].data.shape[1],ylow,yhigh],
          origin="lower")
plt.gca().set_aspect(10);

# %%
plt.imshow(hdul[0].data[ylow:yhigh,:], extent=[0,hdul[0].data.shape[1],ylow,yhigh],
           origin="lower")
plt.gca().set_aspect(10)
plt.plot(xvals, fitted_polymodel(xvals), 'w')
plt.axis((0,hdul[0].data.shape[1],ylow,yhigh));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 4
#       1 plt.imshow(hdul[0].data[ylow:yhigh,:], extent=[0,hdul[0].data.shape[1],ylow,yhigh],
#       2            origin="lower")
#       3 plt.gca().set_aspect(10)
# ----> 4 plt.plot(xvals, fitted_polymodel(xvals), 'w')
#       5 plt.axis((0,hdul[0].data.shape[1],ylow,yhigh));
#
# NameError: name 'fitted_polymodel' is not defined

# %%
xhigh = 4000
polymodel = Polynomial1D(degree=3)
fitted_polymodel = linfitter(polymodel, xvals[(~bad_moments) & (xvals < xhigh)],
                             weighted_yaxis_values[(~bad_moments) & (xvals < xhigh)])
fitted_polymodel

plt.imshow(hdul[0].data[ylow:yhigh,:], extent=[0,hdul[0].data.shape[1],ylow,yhigh],
           origin="lower")
plt.gca().set_aspect(10)
plt.plot(xvals, fitted_polymodel(xvals), 'w')
plt.axis((0,hdul[0].data.shape[1],ylow,yhigh));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 3
#       1 xhigh = 4000
#       2 polymodel = Polynomial1D(degree=3)
# ----> 3 fitted_polymodel = linfitter(polymodel, xvals[(~bad_moments) & (xvals < xhigh)],
#       4                              weighted_yaxis_values[(~bad_moments) & (xvals < xhigh)])
#       5 fitted_polymodel
#       7 plt.imshow(hdul[0].data[ylow:yhigh,:], extent=[0,hdul[0].data.shape[1],ylow,yhigh],
#       8            origin="lower")
#
# NameError: name 'bad_moments' is not defined

# %%
plt.plot(xvals[~bad_moments], weighted_yaxis_values[~bad_moments], 'x', alpha=0.5)
plt.plot(xvals, fitted_polymodel(xvals), color='r');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 plt.plot(xvals[~bad_moments], weighted_yaxis_values[~bad_moments], 'x', alpha=0.5)
#       2 plt.plot(xvals, fitted_polymodel(xvals), color='r');
#
# NameError: name 'bad_moments' is not defined

# %%
plt.plot(xvals[~bad_moments & (xvals < xhigh)],
        weighted_yaxis_values[~bad_moments & (xvals < xhigh)] - fitted_polymodel(xvals[~bad_moments & (xvals < xhigh)]), 'x')
plt.plot(xvals[~bad_moments & (xvals > xhigh)],
        weighted_yaxis_values[~bad_moments & (xvals > xhigh)] - fitted_polymodel(xvals[~bad_moments & (xvals > xhigh)]), 'r+', alpha=0.5)
plt.ylim(-55, 55)
plt.ylabel("Residual (data-model)");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 plt.plot(xvals[~bad_moments & (xvals < xhigh)],
#       2         weighted_yaxis_values[~bad_moments & (xvals < xhigh)] - fitted_polymodel(xvals[~bad_moments & (xvals < xhigh)]), 'x')
#       3 plt.plot(xvals[~bad_moments & (xvals > xhigh)],
#       4         weighted_yaxis_values[~bad_moments & (xvals > xhigh)] - fitted_polymodel(xvals[~bad_moments & (xvals > xhigh)]), 'r+', alpha=0.5)
#       5 plt.ylim(-55, 55)
#
# NameError: name 'bad_moments' is not defined

# %% [markdown]
# # Step 4. Obtain a trace profile

# %%
plt.imshow(hdul[0].data[ylow:yhigh,:], extent=[0,hdul[0].data.shape[1],ylow,yhigh],
           origin="lower")
plt.gca().set_aspect(10)
plt.fill_between(xvals, fitted_polymodel(xvals)-15,
                fitted_polymodel(xvals)+15,
                color='orange', alpha=0.5)
plt.axis((0,hdul[0].data.shape[1],ylow,yhigh));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 4
#       1 plt.imshow(hdul[0].data[ylow:yhigh,:], extent=[0,hdul[0].data.shape[1],ylow,yhigh],
#       2            origin="lower")
#       3 plt.gca().set_aspect(10)
# ----> 4 plt.fill_between(xvals, fitted_polymodel(xvals)-15,
#       5                 fitted_polymodel(xvals)+15,
#       6                 color='orange', alpha=0.5)
#       7 plt.axis((0,hdul[0].data.shape[1],ylow,yhigh));
#
# NameError: name 'fitted_polymodel' is not defined

# %%
# start by taking +/- 15 pixels
npixels_to_cut = 15
trace_center = fitted_polymodel(xvals)
cutouts = np.array([hdul[0].data[int(yval)-npixels_to_cut:int(yval)+npixels_to_cut, ii]
                    for yval, ii in zip(trace_center, xvals)])
cutouts.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 3
#       1 # start by taking +/- 15 pixels
#       2 npixels_to_cut = 15
# ----> 3 trace_center = fitted_polymodel(xvals)
#       4 cutouts = np.array([hdul[0].data[int(yval)-npixels_to_cut:int(yval)+npixels_to_cut, ii]
#       5                     for yval, ii in zip(trace_center, xvals)])
#       6 cutouts.shape
#
# NameError: name 'fitted_polymodel' is not defined

# %%
ax1 = plt.subplot(2,1,1)
ax1.imshow(hdul[0].data[ylow:yhigh,:], extent=[0,hdul[0].data.shape[1],ylow,yhigh],
           origin="lower")
ax1.set_aspect(10)
ax1.set_title("We go from this...")
ax2 = plt.subplot(2,1,2)
ax2.imshow(cutouts.T, 
           origin="lower")
ax2.set_title("...to this")
ax2.set_aspect(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 7
#       5 ax1.set_title("We go from this...")
#       6 ax2 = plt.subplot(2,1,2)
# ----> 7 ax2.imshow(cutouts.T,
#       8            origin="lower")
#       9 ax2.set_title("...to this")
#      10 ax2.set_aspect(10)
#
# NameError: name 'cutouts' is not defined

# %%
mean_trace_profile = (cutouts - background).mean(axis=0)
trace_profile_xaxis = np.arange(-npixels_to_cut, npixels_to_cut)
plt.plot(trace_profile_xaxis, mean_trace_profile)
plt.xlabel("Distance from center")
plt.ylabel("Average source profile");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 mean_trace_profile = (cutouts - background).mean(axis=0)
#       2 trace_profile_xaxis = np.arange(-npixels_to_cut, npixels_to_cut)
#       3 plt.plot(trace_profile_xaxis, mean_trace_profile)
#
# NameError: name 'cutouts' is not defined

# %%
from astropy.modeling.models import Gaussian1D
from astropy.modeling.fitting import LevMarLSQFitter
lmfitter = LevMarLSQFitter()
guess = Gaussian1D(amplitude=mean_trace_profile.max(), mean=0, stddev=5)
fitted_trace_profile = lmfitter(model=guess, x=trace_profile_xaxis, y=mean_trace_profile)
model_trace_profile = fitted_trace_profile(trace_profile_xaxis)
fitted_trace_profile

plt.plot(trace_profile_xaxis, mean_trace_profile, label='data')
plt.plot(trace_profile_xaxis, model_trace_profile, label='model')
plt.legend(loc='best')
plt.xlabel("Distance from center")
plt.ylabel("Average source profile");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 4
#       2 from astropy.modeling.fitting import LevMarLSQFitter
#       3 lmfitter = LevMarLSQFitter()
# ----> 4 guess = Gaussian1D(amplitude=mean_trace_profile.max(), mean=0, stddev=5)
#       5 fitted_trace_profile = lmfitter(model=guess, x=trace_profile_xaxis, y=mean_trace_profile)
#       6 model_trace_profile = fitted_trace_profile(trace_profile_xaxis)
#
# NameError: name 'mean_trace_profile' is not defined

# %% [markdown]
# # Step 5. Extract the traced spectrum

# %%
average_spectrum = (cutouts - background).mean(axis=1)
plt.plot(average_spectrum);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 average_spectrum = (cutouts - background).mean(axis=1)
#       2 plt.plot(average_spectrum);
#
# NameError: name 'cutouts' is not defined

# %%
trace_avg_spectrum = np.array([np.average(
    hdul[0].data[int(yval)-npixels_to_cut:int(yval)+npixels_to_cut, ii] - background,
    weights=mean_trace_profile)
                               for yval, ii in zip(trace_center, xvals)])

gaussian_trace_avg_spectrum = np.array([np.average(
    hdul[0].data[int(yval)-npixels_to_cut:int(yval)+npixels_to_cut, ii] - background,
    weights=model_trace_profile)
                               for yval, ii in zip(trace_center, xvals)])


plt.plot(average_spectrum, label="Direct Average")
plt.plot(trace_avg_spectrum, label='Trace-weighted average')
plt.plot(gaussian_trace_avg_spectrum, label='Gaussian-model-Trace-weighted average', alpha=0.5, linewidth=0.5, color='r')
plt.legend(loc='best');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 4
#       1 trace_avg_spectrum = np.array([np.average(
#       2     hdul[0].data[int(yval)-npixels_to_cut:int(yval)+npixels_to_cut, ii] - background,
#       3     weights=mean_trace_profile)
# ----> 4                                for yval, ii in zip(trace_center, xvals)])
#       6 gaussian_trace_avg_spectrum = np.array([np.average(
#       7     hdul[0].data[int(yval)-npixels_to_cut:int(yval)+npixels_to_cut, ii] - background,
#       8     weights=model_trace_profile)
#       9                                for yval, ii in zip(trace_center, xvals)])
#      12 plt.plot(average_spectrum, label="Direct Average")
#
# NameError: name 'trace_center' is not defined
